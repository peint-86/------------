# %%
import numpy as np
def cos_sim(vec1,vec2):
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
import json
import csv
import numpy as np
import pandas as pd

# %%
import json
import csv
import numpy as np
import pandas as pd
def course_list():
    file=open("course_list.csv")
    file=csv.reader(file)
    file=list(file)
    print(file.index("'プログラミング基礎'"))
    course=[]
    for c in file:
        course.append(c)
    return course
corses=course_list()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 14
#      12         course.append(c)
#      13     return course
# ---> 14 corses=course_list()
#
# Cell In[16], line 9, in course_list()
#       7 file=csv.reader(file)
#       8 file=list(file)
# ----> 9 print(file.index("'プログラミング基礎'"))
#      10 course=[]
#      11 for c in file:
#
# ValueError: "'プログラミング基礎'" is not in list

# %%
import json
import csv
import numpy as np
import pandas as pd
def vocab_list():
    file=open("keyword_list.csv")
    file=csv.reader(file)
    keywor=[]
    for c in file:
        keywor.append(c)
    return keywor
vocab=vocab_list()
print(vocab.index(['プログラミング']))
# Out:
# ['演習']
# ['特殊']
# ['講義']
# ['科学']
# ['研究']
# ['工学']
# ['社会']
# ['コース']
# ['日本']
# ['文化']
# ['文学']
# ['理学']
# ['化学']
# ['語学']
# ['実習']
# ['生物']
# ['共通']
# ['基礎']
# ['情報']
# ['特別']
# ['英語']
# ['環境']
# ['シス']
# ['システム']
# ['国語']
# ['国際']
# ['専門']
# ['数理']
# ['経済']
# ['概論']
# ['実験']
# ['言語']
# ['力学']
# ['教育']
# ['日本語']
# ['物理']
# ['史学']
# ['応用']
# ['中国']
# ['フランス']
# ['現代']
# ['心理']
# ['生命数学']
# ['開講']
# ['分析']
# ['心理学']
# ['教養']
# ['思想']
# ['統計']
# ['ドイツ']
# ['政治']
# ['論文']
# ['中国語']
# ['解析']
# ['アメリカ']
# ['哲学']
# ['アジア']
# ['建築']
# ['物質']
# ['イタリア']
# ['第一']
# ['科目']
# ['技術']
# ['倫理']
# ['グローバル']
# ['朝鮮']
# ['設計']
# ['韓国']
# ['物理学']
# ['地域']
# ['国文学']
# ['テクスト']
# ['社会学']
# ['地球']
# ['生物学']
# ['中級']
# ['材料']
# ['動物']
# ['西洋']
# ['外国語']
# ['総合']
# ['フランス語']
# ['理論']
# ['初級']
# ['経済学分子']
# ['自然']
# ['ドイツ語']
# ['国語学']
# ['構造']
# ['宇宙']
# ['指導']
# ['社会科']
# ['人類']
# ['都市']
# ['ロシア']
# ['解析学']
# ['生命科学']
# ['基礎科学']
# ['社会科学']
# ['比較']
# ['卒業']
# ['森林']
# ['歴史']
# ['経営']
# ['プロジェクト']
# ['航空']
# ['情報学']
# ['情報工学']
# ['イタリア語']
# ['資源']
# ['量子']
# ['ラテンアメリカ']
# ['概説']
# ['計画']
# ['エネルギー']
# ['人類学']
# ['自然科学']
# ['上級']
# ['英語学']
# ['環境学']
# ['卒業論文']
# ['植物']
# ['生態']
# ['地理']
# ['統合']
# ['芸術']
# ['英米文学教育法']
# ['高度']
# ['宗教']
# ['相関']
# ['関係']
# ['広域']
# ['会話']
# ['日本史']
# ['惑星']
# ['科学技術']
# ['国際関係']
# ['計算']
# ['イギリス']
# ['電気']
# ['機械']
# ['中国語学']
# ['文明']
# ['考古学']
# ['中国文学']
# ['認知']
# ['数理科学']
# ['進化']
# ['情報科']
# ['スペイン']
# ['理工学']
# ['航空宇宙']
# ['美術史']
# ['西洋史']
# ['生体']
# ['農業']
# ['生理']
# ['電子']
# ['マテ']
# ['統計学']
# ['東西文明']
# ['プログラミング']
# ['政策']
# ['調査']
# ['情報科学']
# ['有機']
# ['代数']
# ['看護']
# ['空間地域文化']
# ['理I']
# ['量子力学']
# ['代数学']
# ['金融']
# ['東洋']
# ['近代']
# ['バイオ']
# ['言語学']
# ['文化人類学']
# ['健康']
# ['地中海']
# ['フランス文学']
# ['スペイン語']
# ['幾何']
# ['後期']
# ['製図']
# ['臨床']
# ['幾何学']
# ['東欧']
# ['制御']
# ['精密']
# ['社会心理学']
# ['国際社会']
# ['ヨーロッパ']
# ['行動']
# ['有機化学']
# ['国際関係論']
# ['日本文化']
# ['ロシア語']
# ['組織']
# ['マテリアル']
# ['スラヴ']
# ['フランス語学']
# ['体力']
# ['学際']
# ['生理学']
# ['生態学']
# ['講読']
# ['看護学']
# ['インド哲学']
# ['仏教']
# ['生産人間']
# ['開発']
# ['原典']
# ['表象']
# ['現代思想']
# ['経済史']
# ['輪講']
# ['東洋史']
# ['東アジア']
# ['学習']
# ['セミナー']
# ['計測']
# ['ドイツ文学']
# ['古典']
# ['精読']
# ['システム工学']
# ['流体']
# ['管理']
# ['宗教学']
# ['倫理学']
# ['身体']
# ['スポーツ']
# ['統計力学']
# ['物理化学']
# ['ラテン語']
# ['環境工学']
# ['少人数']
# ['行政']
# ['高分子']
# ['イタリア文学']
# ['細胞']
# ['遺伝']
# ['公共']
# ['専修']
# ['デザイン']
# ['都市工学']
# ['物性']
# ['確率']
# ['印度']
# ['実践']
# ['コミュニケーション']
# ['機能']
# ['基盤入門']
# ['データ']
# ['アジア地域']
# ['ラテンアメリカ研究']
# ['資料']
# ['産業']
# ['マネジメント']
# ['博物館']
# ['流体力学']
# ['文学史']
# ['宗教史']
# ['処理']
# ['物質科学']
# ['日本経済']
# ['発生']
# ['確率統計']
# ['数学I']
# ['アラビア語']
# ['作文']
# ['遺伝学']
# ['教育学']
# ['野外']
# ['固体']
# ['神経']
# ['集中']
# ['機構']
# ['方法']
# ['エシックス']
# ['反応']
# ['多様性']
# ['理II']
# ['読解']
# ['死生学']
# ['電磁']
# ['微生物']
# ['回路']
# ['水圏']
# ['医学']
# ['推進']
# ['美学']
# ['イスラム']
# ['分析化学']
# ['外交政治学']
# ['民族']
# ['メディア']
# ['フィールド']
# ['民法']
# ['総論']
# ['材料力学']
# ['システム情報']
# ['無機']
# ['磁気']
# ['航空機']
# ['近代文学']
# ['西洋古典学']
# ['芸術学']
# ['医療']
# ['比較文化']
# ['交流']
# ['行動科学']
# ['生化学']
# ['現代社会']
# ['法学']
# ['政治経済']
# ['ため']
# ['比較文学']
# ['疫学']
# ['表現']
# ['リング']
# ['夏季']
# ['海洋']
# ['計数']
# ['プロセス']
# ['手法']
# ['空気']
# ['獣医']
# ['食品']
# ['国際政治']
# ['計量']
# ['電磁気学']
# ['複素解析']
# ['シミュレーション']
# ['技法']
# ['循環']
# ['熱力学地域研究']
# ['北アメリカ']
# ['ギリシア語']
# ['造形']
# ['利用']
# ['会計']
# ['教育社会学']
# ['制御工学']
# ['応用数学']
# ['ソフトウェア']
# ['文章']
# ['通論']
# ['空気力学']
# ['解剖']
# ['天文学']
# ['木質']
# ['農学']
# ['衛生学']
# ['栄養']
# ['文化科学']
# ['脳科学']
# ['批評']
# ['表象文化論']
# ['発達']
# ['方法論']
# ['神経科学']
# ['栄養学']
# ['解剖学']
# ['生体高分子']
# ['無機化学']
# ['生物多様性']
# ['薬学']
# ['薬理学']
# ['医薬']
# ['アメリカ文学']
# ['財務']
# ['戦略']
# ['マクロ']
# ['ファイナンス']
# ['バイオマス']
# ['病理学']
# ['微生物学']
# ['安全知能']
# ['インターンシップ']
# ['精密工学']
# ['振動']
# ['固体物理']
# ['発生学']
# ['惑星物理学']
# ['動物学']
# ['外科']
# ['昆虫']
# ['商法']
# ['思想史']
# ['分野']
# ['協力']
# ['応用倫理学']
# ['トレーニング']
# ['細胞生物学']
# ['数学II']
# ['分子生物学']
# ['科学哲学']
# ['地球科学']
# ['国際法']
# ['英語圏']
# ['情報処理']
# ['ヒンディー語']
# ['ポルトガル語']
# ['公衆衛生']
# ['法制史']
# ['原論']
# ['労働経済']
# ['数量']
# ['経営史']
# ['現代日本']
# ['学校']
# ['人体']
# ['緑地']
# ['数理工学']
# ['機械工学']
# ['デバイス']
# ['冬季']
# ['実地']
# ['電気工学']
# ['コンピュータ物理数学']
# ['自動']
# ['人文']
# ['前期']
# ['文芸']
# ['および']
# ['連続']
# ['現象']
# ['素材']
# ['土壌']
# ['水生']
# ['第２部']
# ['第１部']
# ['フィールドワーク']
# ['ビジネス']
# ['科学技術社会論']
# ['文法']
# ['認知科学']
# ['技術経営']
# ['国際協力']
# ['卒業研究']
# ['数値']
# ['最適化']
# ['メディア論']
# ['文化史']
# ['教職']
# ['経営戦略']
# ['保険']
# ['事情']
# ['財政']
# ['行政法']
# ['計量経済学']
# ['マクロ経済学']
# ['ミクロ経済学']
# ['放射線']
# ['社会教育']
# ['教育行政']
# ['運動']
# ['大気']
# ['ロボット']
# ['半導体']
# ['創造']
# ['機器アカデミック']
# ['アルゴリズム']
# ['化学工学']
# ['エレクトロニクス']
# ['建築構造']
# ['光学']
# ['第五']
# ['連続体']
# ['弾性']
# ['建築史']
# ['ゲノム']
# ['免疫']
# ['精神']
# ['地理学']
# ['天体']
# ['水産']
# ['民事訴訟法']
# ['刑事']
# ['刑法']
# ['医薬品']
# ['英語科']
# ['スポーツ科学']
# ['理科教育']
# ['数学科']
# ['問題']
# ['インタープリター']
# ['超分子']
# ['脳神経']
# ['連続体力学']
# ['実解析']
# ['量子化学']
# ['構成']
# ['バイオインフォマティクス']
# ['リスク']
# ['社会技術']
# ['生態系']
# ['エネルギー資源']
# ['エネルギー工学']
# ['文献']
# ['モデル']
# ['地域社会']
# ['体系']
# ['南アジアブラジル']
# ['ラテンアメリカ文学']
# ['現代史']
# ['言語教育']
# ['民族誌']
# ['映像']
# ['日本手話']
# ['インドネシア語']
# ['広東語']
# ['活動']
# ['トルコ語']
# ['ベトナム語']
# ['小児']
# ['人口']
# ['農村']
# ['感染症']
# ['デリバティブ']
# ['企業']
# ['フード']
# ['行政学']
# ['博物館学']
# ['教育心理学']
# ['地球環境']
# ['プラズマ']
# ['交通']
# ['微分方程式']
# ['水理学']
# ['機構学']
# ['自動車']
# ['エンジン']
# ['ゼミ']
# ['加工']
# ['プレゼンテーション']
# ['電子回路']
# ['インテンシブ']
# ['信号']
# ['通信']
# ['応用化学']
# ['建築材料']
# ['設備']
# ['保健学']
# ['宇宙工学']
# ['構造力学ＩＶ']
# ['臨海']
# ['西洋哲学']
# ['哲学概論']
# ['各論']
# ['形態']
# ['計算機']
# ['植物学']
# ['育種学']
# ['分類']
# ['ソ連']
# ['国法']
# ['道徳']
# ['公共性']
# ['こころ']
# ['人間科学']
# ['まち']
# ['芸術作品']
# ['生活']
# ['原理']
# ['地理歴史']
# ['表現論']
# ['リテラシー']
# ['再生']
# ['制御論']
# ['物性物理学']
# ['素粒子物理学']
# ['一般']
# ['相対論']
# ['システム生物学']
# ['測定']
# ['環境問題']
# ['先進']
# ['作成']
# ['持続']
# ['可能']
# ['公共政策']
# ['社会学研究']
# ['組織論']
# ['政治・経済']
# ['中東']
# ['変遷']
# ['旧ソ連横断']
# ['個別']
# ['アジア文化']
# ['日本語学']
# ['テクノロジー']
# ['イメージ']
# ['課題']
# ['社会調査']
# ['アカデミックスキル']
# ['ポーランド語']
# ['セルビア・クロアチア語']
# ['体験']
# ['政治学史']
# ['近現代']
# ['ゼミナール']
# ['租税法']
# ['総合科学']
# ['労働法']
# ['投資']
# ['社会保障']
# ['証券']
# ['実証']
# ['理Ⅰ']
# ['管理会計']
# ['財務会計']
# ['経営管理']
# ['資本主義']
# ['マーケティング']
# ['日本経営']
# ['評価']
# ['形態学']
# ['生物統計学']
# ['免疫学']
# ['金融法']
# ['発達心理学']
# ['図書館']
# ['教授']
# ['統計法']
# ['相談']
# ['政策学']
# ['疾病']
# ['ヒューマン']
# ['モデリングライフサイクル']
# ['領域']
# ['知識']
# ['研修']
# ['量子論']
# ['計測工学']
# ['マイニング']
# ['エンジニアリング']
# ['先端']
# ['福祉']
# ['認識']
# ['機械力学']
# ['メカトロニクス']
# ['流れ']
# ['熱工学']
# ['コンテンツ']
# ['電気回路']
# ['材料工学']
# ['信号処理']
# ['数値解析']
# ['反応工学']
# ['結晶学']
# ['信頼性']
# ['ものづくり']
# ['ＶＬＳＩ']
# ['光電子']
# ['アントレプレナーシップ']
# ['音声']
# ['化学反応']
# ['高分子化学']
# ['沿岸']
# ['途上国']
# ['世界']
# ['景観']
# ['序論']
# ['研究倫理']
# ['計算科学']
# ['建築設備']
# ['住宅']
# ['毒性学']
# ['基礎看護学']
# ['情報システム学']
# ['学外ＩＩＩ']
# ['南欧']
# ['植物生理学']
# ['系統']
# ['地質学']
# ['観測']
# ['リモートセンシング']
# ['天然']
# ['酵素']
# ['本郷']
# ['職業']
# ['固体物理学']
# ['測量']
# ['講究']
# ['土壌学']
# ['保全']
# ['産業動物']
# ['細菌学']
# ['獣医学']
# ['ウイルス学']
# ['生物工学']
# ['木材']
# ['汎論']
# ['分類学']
# ['化合物']
# ['政治史']
# ['刑事訴訟法']
# ['第３部']
# ['生命倫理']
# ['現象学']
# ['教育課程']
# ['複合']
# ['公民']
# ['招待']
# ['チュートリアル']
# ['アジア太平洋']
# ['精神医学']
# ['特別活動']
# ['道徳教育']
# ['ライティング']
# ['バイオメカニクス']
# ['適応']
# ['公共哲学分光学']
# ['常微分方程式']
# ['動力学']
# ['カオス']
# ['バイオイメージング']
# ['高次']
# ['自然環境']
# ['サステナビリティ']
# ['経済政策']
# ['生物圏']
# ['環境経済学']
# ['食の安全']
# ['安心']
# ['進化論']
# ['食料']
# ['消費']
# ['法学研究']
# ['開発経済学']
# ['社会思想']
# ['取引']
# ['国際機構']
# ['秩序']
# ['アフリカ']
# ['近現代史']
# ['東南アジア']
# ['中東地域']
# ['ドイツ語圏']
# ['イギリス文学']
# ['様態論']
# ['卒論']
# ['日本文学']
# ['芸能']
# ['対照']
# ['類型']
# ['民俗学']
# ['と食']
# ['音響']
# ['台湾語']
# ['サンスクリット語']
# ['上海語']
# ['ニュース']
# ['ヘブライ語']
# ['タイ語ペルシャ語']
# ['モンゴル語']
# ['こと']
# ['教育哲学']
# ['日本教育史']
# ['発展途上国']
# ['経済法']
# ['トピックス']
# ['理Ⅱ']
# ['中国法']
# ['比較法']
# ['日本法制史']
# ['ローマ法']
# ['近代法']
# ['松井']
# ['環境政策']
# ['流通']
# ['ベンチャ']
# ['金融市場']
# ['佐藤']
# ['世界経済']
# ['阿部']
# ['久保川']
# ['尾山']
# ['加藤']
# ['下津']
# ['アクチュアリー']
# ['ワークショップ']
# ['フロンティア']
# ['ゲーム理論']
# ['雇用']
# ['影響']
# ['イスラーム']
# ['法哲学']
# ['法社会学']
# ['特許法']
# ['疾患']
# ['代謝']
# ['天然物化学']
# ['医事法']
# ['学校経営']
# ['高等教育']
# ['バリアスタディーズ']
# ['教育方法学']
# ['行政調査']
# ['生涯学習']
# ['ダイナミクス']
# ['学習心理学']
# ['ストレス']
# ['教育実習']
# ['ドイツ法']
# ['憲法']
# ['災害']
# ['水質']
# ['コンピューティング']
# ['形成']
# ['コロキウム']
# ['プロジェクトマネジメント']
# ['IＣ']
# ['核融合']
# ['都市交通']
# ['都市計画']
# ['ビーム']
# ['可視化']
# ['海外']
# ['創成']
# ['システム設計']
# ['レジリエンス']
# ['伝熱']
# ['変換']
# ['まちづくり']
# ['マイクロ']
# ['機械学習']
# ['対象']
# ['自動車工学']
# ['波動']
# ['コントロール']
# ['ロボティクス']
# ['アクチュエータ']
# ['IＢ']
# ['センサ']
# ['ナノ']
# ['IＡ']
# ['人工']
# ['語彙漢字']
# ['表面']
# ['電力']
# ['大要']
# ['ネットワーク']
# ['ハードウエア']
# ['生態工学']
# ['経済工学']
# ['分離工学']
# ['プロセスシステム工学']
# ['スパコン']
# ['情報通信']
# ['アーキテクチャ']
# ['地震']
# ['構造物']
# ['地盤']
# ['水文学']
# ['イノベーション']
# ['土地']
# ['バイオテクノロジー']
# ['経営学']
# ['鉄筋コンクリート構造']
# ['鉄骨構造']
# ['法規']
# ['荷重']
# ['外力']
# ['複雑']
# ['施工']
# ['ガスタービン']
# ['母性']
# ['支援']
# ['チベット語']
# ['ペルシア語']
# ['ギリシャ語']
# ['在宅']
# ['老年']
# ['ジェットエンジン']
# ['電算機']
# ['ＶＩ']
# ['比較言語学']
# ['音声学']
# ['古文書']
# ['集団系統分類学']
# ['人体解剖学']
# ['配列']
# ['第2部']
# ['第1部']
# ['輻射']
# ['気象学']
# ['宇宙空間物理学']
# ['地球流体力学']
# ['内部']
# ['星間']
# ['課題研究']
# ['巡検']
# ['生体物質']
# ['分子遺伝学']
# ['生物物理化学']
# ['地形']
# ['気候']
# ['海洋学']
# ['岩石']
# ['地球化学']
# ['実験物理学']
# ['論理']
# ['離散']
# ['場の量子論']
# ['数学III']
# ['食品衛生']
# ['緑地環境学']
# ['森林科学']
# ['森林利用学']
# ['野生動物']
# ['森林政策学']
# ['経理']
# ['風景']
# ['造林']
# ['応用微生物学']
# ['理III']
# ['牧場']
# ['保全生態学']
# ['漁業']
# ['ランドスケープ']
# ['エコロジー']
# ['寄生虫学実験動物']
# ['小動物']
# ['内科']
# ['臨床実習']
# ['繁殖']
# ['循環器病学']
# ['泌尿']
# ['界面']
# ['農村計画']
# ['生殖']
# ['動態']
# ['木質材料']
# ['農業経営']
# ['感染症学']
# ['要素']
# ['呼吸']
# ['内分泌']
# ['外科学']
# ['消化器']
# ['医事']
# ['園芸学']
# ['栽培']
# ['作物']
# ['タンパク質']
# ['樹木']
# ['脊椎']
# ['魚類']
# ['フランス法']
# ['国際私法']
# ['英米法']
# ['知的財産']
# ['財政学']
# [' ']
# ['イギリス歴史社会論I']
# ['卒論演習[言語態・テクスト文化論コース]']
# ['現代哲学演習（２）']
# ['言語文化論特殊研究（２７）']
# ['言語文化論特殊研究（２３）']
# ['言語情報処理I[言語態・テクスト文化論コース]']
# ['言語文化論特殊研究（２４）']
# ['現代思想演習']
# ['言語文化論特殊研究（２６）']
# ['言語と認知I[言語態・テクスト文化論コース]個別言語特殊演習（１）']
# ['現代哲学演習（１）']
# ['原典講読特殊演習（１）[学際言語科学コース]']
# ['原典講読特殊演習（２）[学際言語科学コース]']
# ['東アジア文化論']
# ['日本歴史文化論']
# ['論文指導[学際日本文化論コース]']
# ['学際日本文化論演習I']
# ['日本文化資料読解I']
# ['言語文化論特殊研究（２８）']
# ['日本文化研究法II']
# ['国際日本文化研究']
# ['言語の変異・変化I']
# ['日本言語文化論']
# ['学際日本文化論演習V']
# ['日本文化資料読解II']
# ['現代思想特殊演習III']
# ['言語と人間II']
# ['学際日本文化論演習IV']
# ['学際日本文化論演習II']
# ['現代思想（２）']
# ['現代思想（１）']
# ['比較文学比較文化論演習III']
# ['日本文化研究法I']
# ['学際日本文化論演習III']
# ['現代思想特殊研究II（１）']
# ['現代哲学特殊研究III']
# ['現代哲学特殊研究II']
# ['現代哲学']
# ['文化社会論演習[現代思想コース]']
# ['比較文化論III']
# ['文化社会論[現代思想コース]']
# ['現代哲学特殊研究I']
# ['言語文化論特殊研究（２５）']
# ['現代哲学特殊演習III（２）']
# ['現代思想特殊研究I']
# ['現代哲学特殊演習III（１）']
# ['現代哲学特殊演習II（１）']
# ['現代思想特殊演習I（１）']
# ['現代哲学特殊演習II（２）']
# ['現代思想特殊研究III']
# ['倫理宗教論[現代思想コース]']
# ['テクスト文化論演習テクスト文化論基礎']
# ['言語態研究基礎']
# ['現代哲学特殊演習I（１）']
# ['卒業論文演習II[現代思想コース]']
# ['言語データ分析基礎']
# ['言語構造論特殊演習（１）']
# ['基礎言語理論III: 音の体系']
# ['言語構造論特殊演習（２）']
# ['日本文化資料研究I']
# ['東アジア文化資料研究I']
# ['言語構造論特殊演習（３）']
# ['日本文化資料研究II']
# ['現代哲学特殊演習I（２）']
# ['日本文学']
# ['芸能・芸術論']
# ['メディア文化論[学際日本文化論コース]']
# ['言語態研究演習']
# ['東洋古典学']
# ['言語と社会I']
# ['言語情報処理I[学際言語科学コース]']
# ['言語と認知I[学際言語科学コース]']
# ['言語の対照と類型II（２）']
# ['個別言語特殊演習（３）']
# ['言語の対照と類型II（１）']
# ['テクスト分析演習IV（８）']
# ['言語と社会II']
# ['倫理宗教論演習[現代思想コース]']
# ['テクスト分析演習III（１１）']
# ['テクスト分析演習II（１４）']
# ['日本思想']
# ['テクスト分析演習I（１２）']
# ['テクスト分析演習II（１５）']
# ['テクスト分析演習III（１０）']
# ['テクスト分析演習III（９）']
# ['言語科学への招待']
# ['言語理論III']
# ['基礎言語理論I：形の体系']
# ['日本語学']
# ['言語理論II']
# ['言語理論I']
# ['メディア文化論[言語態・テクスト文化論コース]']
# ['日本語学II']
# ['テクスト分析演習I（１３）言語文化横断論演習（３）']
# ['言語情報処理II[学際言語科学コース]']
# ['言語教育・学習論I[言語態・テクスト文化論コース]']
# ['テクスト分析演習V（１３）']
# ['テクスト分析演習V（１２）']
# ['言語教育・学習論II[学際言語科学コース]']
# ['言語文化横断論演習[学際言語科学コース]']
# ['テクスト分析演習V（１１）']
# ['言語教育・学習論I[学際言語科学コース]']
# ['テクスト分析演習IV（９）']
# ['原典講読特殊演習（６）[言語態・テクスト文化論コース]']
# ['ヨーロッパの地理[イギリス研究コース]']
# ['イギリス言語様態論']
# ['イギリス思想変遷論']
# ['イギリス言語芸術論II']
# ['イギリス表象芸術論']
# ['広域英語圏地域論[イギリス研究コース]']
# ['イギリス政治文化論']
# ['イギリス言語芸術論I']
# ['原典講読特殊演習（７）[言語態・テクスト文化論コース]']
# ['特殊講義II[イギリス研究コース]']
# ['特殊研究演習VI[イギリス研究コース]']
# ['特殊研究演習III[イギリス研究コース]']
# ['ヨーロッパ政治論a[イギリス研究コース]']
# ['特殊研究演習IV[イギリス研究コース]']
# ['特殊研究演習II[イギリス研究コース]']
# ['言語理論IV']
# ['特殊研究演習I[イギリス研究コース]']
# ['イギリス思想テクスト演習']
# ['広域英語圏文化論演習[イギリス研究コース]']
# ['調査研究実習']
# ['比較文学比較文化特殊研究I']
# ['比較文学比較文化特殊研究II']
# ['文化人類学特殊講義（民族誌作成）']
# ['文化人類学特殊講義（参加概念の再検討）']
# ['文化人類学特殊講義（映像人類学）']
# ['表象文化論特殊研究演習IV']
# ['文化人類学基礎演習']
# ['資料・文献調査法']
# ['専門スペイン語（９）a']
# ['専門スペイン語（４）a']
# ['専門ドイツ語（１５）']
# ['専門スペイン語（３）a比較研究の理論']
# ['専門英語（１３０）']
# ['専門英語（１２１）']
# ['専門ドイツ語（１４）']
# ['専門英語（１２９）']
# ['専門スペイン語（８）a']
# ['専門スペイン語（７）a']
# ['専門ドイツ語（２４）']
# ['専門英語（１２７）']
# ['文化人類学特殊講義（卒論演習）']
# ['専門英語（１２８）']
# ['専門英語（１３１）']
# ['専門ドイツ語（１７）']
# ['専門フランス語（１８）']
# ['専門ドイツ語（１６）']
# ['専門フランス語（１９）']
# ['専門英語（１２４）b']
# ['専門英語（１３４）']
# ['専門フランス語（１６）']
# ['専門フランス語（１５）']
# ['専門フランス語（１７）']
# ['専門ドイツ語（２１）']
# ['専門英語（１３２）']
# ['専門ドイツ語（２０）a']
# ['専門ドイツ語（１９）']
# ['専門ドイツ語（２０）b']
# ['専門ドイツ語（１８）b']
# ['専門ドイツ語（１８）a']
# ['専門英語（１２１）b']
# ['専門英語（１２４）a']
# ['専門英語（１２４）']
# ['専門ドイツ語（１３）']
# ['専門フランス語（２７）']
# ['専門英語（１２１）a']
# ['専門フランス語（２６）']
# ['専門ドイツ語（２２）']
# ['専門フランス語（２３）']
# ['専門英語（１２０）']
# ['専門フランス語（２１）']
# ['専門フランス語（２５）']
# ['専門英語（１１９）']
# ['専門英語（１１７）']
# ['専門英語（１１６）専門フランス語（２２）']
# ['専門英語（１１４）']
# ['専門英語（１１５）']
# ['専門英語（１１３）']
# ['専門中国語（３）']
# ['専門中国語（２）']
# ['専門英語（１１２）']
# ['専門英語（１１１）']
# ['専門ロシア語（６）']
# ['専門ロシア語（５）']
# ['専門韓国朝鮮語（４）']
# ['専門ロシア語（４）']
# ['専門韓国朝鮮語（３）']
# ['専門イタリア語（１１）']
# ['専門アラビア語（２）']
# ['専門イタリア語（１０）']
# ['専門ドイツ語（２３）']
# ['専門イタリア語（８）']
# ['専門イタリア語（９）']
# ['専門韓国朝鮮語（２）']
# ['専門スペイン語（１０）a']
# ['民俗学']
# ['応用人類学I']
# ['地域民族誌II']
# ['文化人類学理論III']
# ['専門フランス語（２０）']
# ['文化人類学理論I']
# ['フィールド演習']
# ['社会人類学理論I']
# ['文化人類学理論II']
# ['卒業論文演習[文化人類学コース]']
# ['専門英語（１１８）']
# ['表象システム論']
# ['専門英語（１３３）']
# ['専門イタリア語（７）']
# ['表象文化基礎論']
# ['文化人類学特殊演習（テクノロジーと文化）']
# ['文化人類学特殊演習(イメージの人類学 2)']
# ['文化人類学特殊講義（自然人類学）']
# ['文化人類学特殊講義（民俗学の思想と現代的課題 3）']
# ['日本文化研究II']
# ['日本文化研究I']
# ['文化人類学特殊演習（中東の民族誌を読む）歴史と文化I']
# ['文化人類学特殊演習a（ロシア・東欧の民族）']
# ['専門日本語（５）']
# ['文化人類学基礎論']
# ['文化人類学特殊演習（宗教と食）']
# ['専門日本語（４）']
# ['文化人類学特殊講義（民族地理論）']
# ['専門ラテン語（８）']
# ['専門ラテン語（６）']
# ['専門ラテン語（１０）']
# ['専門ラテン語（９）']
# ['専門ギリシア語（３）']
# ['専門ラテン語（７）']
# ['地域民族誌III']
# ['表象文化論特殊研究演習II']
# ['文化人類学特殊演習（社会調査法）']
# ['言語芸術論I']
# ['表象メディア論演習']
# ['映像芸術論I']
# ['表象文化論特殊研究演習I']
# ['造形空間芸術論II']
# ['映像芸術論II']
# ['舞台芸術論I']
# ['伝統芸能論II']
# ['表象文化論実習II']
# ['表象文化論特殊講義I']
# ['音響芸術論I']
# ['表象文化史']
# ['比較日本文化論演習']
# ['造形空間芸術論I']
# ['比較文学比較文化論演習I']
# ['表象メディア論']
# ['比較文学比較文化論演習II']
# ['比較日本文化論I']
# ['比較文化論II']
# ['比較芸術論II']
# ['比較文化論I']
# ['表象文化基礎論演習']
# ['比較文学論II']
# ['表象文化史演習']
# ['専門ギリシア語（４）']
# ['比較芸術論I']
# ['芸術作品分析法II比較文学論I']
# ['卒業論文演習[比較文学比較芸術コース]']
# ['表象文化論実習I']
# ['テクスト精読法II']
# ['芸術作品分析法I']
# ['テクスト精読法III']
# ['比較日本文化論II']
# ['テクスト精読法I']
# ['共通日本語（１）b']
# ['専門英語（９０）']
# ['共通ラテン語（６）']
# ['専門英語（１１０）']
# ['共通日本語（１）a']
# ['専門英語（９１）']
# ['共通イタリア語（５）']
# ['共通韓国朝鮮語（３）']
# ['共通イタリア語（４）']
# ['共通スペイン語（８）（会話）']
# ['専門英語（１０１）']
# ['ヒンディー語（３）']
# ['日本語（４２）中級総合（L3）']
# ['日本語（３６）アカデミックスキル（総合）（L6-L7）']
# ['共通スペイン語（２８）（初級）']
# ['共通中国語（６２）（作文）']
# ['台湾語（１）（中級）']
# ['サンスクリット語（１）']
# ['日本語（４６）自然な話し方と敬語（L4-L6）']
# ['共通中国語（６０）（会話）']
# ['共通中国語（５２）（精読）']
# ['共通中国語（５４）（会話）']
# ['共通中国語（５３）（会話）']
# ['共通スペイン語（２７）（会話）']
# ['共通中国語（５５）（作文）']
# ['日本語（３４）アカデミックスキル（総合）（L4-L5）']
# ['共通ラテン語（３）']
# ['共通ラテン語（５）']
# ['共通中国語（５７）（精読）']
# ['共通ラテン語（２）']
# ['共通ラテン語（４）']
# ['共通ギリシア語（４）']
# ['共通ラテン語（１）']
# ['共通中国語（６１）（作文）']
# ['共通ギリシア語（２）日本語（１０２）チュートリアル（L2-L6）']
# ['共通中国語（５８）（精読）']
# ['共通ギリシア語（６）']
# ['日本手話（１）']
# ['共通ギリシア語（３）']
# ['共通中国語（５６）（作文）']
# ['日本手話（２）']
# ['上海語（１）（初級）']
# ['共通ギリシア語（５）']
# ['インドネシア語（３）']
# ['インドネシア語（２）']
# ['日本語（３２）アカデミックスキル（総合）（L3-L4）']
# ['上海語（２）（初級）']
# ['広東語（２）（中級）']
# ['共通スペイン語（７）（初級）']
# ['広東語（３）（初級）']
# ['インドネシア語（４）']
# ['サンスクリット語（２）']
# ['広東語（４）（中級）']
# ['共通スペイン語（５）（演習）']
# ['共通スペイン語（１）（会話）']
# ['共通韓国朝鮮語（２）']
# ['共通スペイン語（４）（作文）']
# ['共通イタリア語（１８）']
# ['共通スペイン語（２）（会話）']
# ['共通イタリア語（９）']
# ['共通イタリア語（１０）']
# ['共通イタリア語（１７）']
# ['共通スペイン語（６）（演習）']
# ['共通スペイン語（３）（作文）']
# ['共通イタリア語（６）']
# ['共通アラビア語（１０）']
# ['共通イタリア語（７）']
# ['共通イタリア語（８）']
# ['共通アラビア語（９）']
# ['共通アラビア語（６）']
# ['共通アラビア語（７）']
# ['共通アラビア語（５）']
# ['共通アラビア語（２）']
# ['共通韓国朝鮮語（１）']
# ['共通イタリア語（２）']
# ['共通アラビア語（１）']
# ['共通イタリア語（１）共通イタリア語（３）']
# ['共通アラビア語（８）']
# ['共通アラビア語（３）']
# ['共通ポルトガル語（２）（初級）']
# ['共通ポルトガル語（４）（中級）']
# ['共通ポルトガル語（１）（初級）']
# ['共通韓国朝鮮語（２２）（初級）']
# ['共通スペイン語（３０）（初級）']
# ['インドネシア語（１）']
# ['共通韓国朝鮮語（１０）']
# ['共通韓国朝鮮語（８）']
# ['共通韓国朝鮮語（２６）']
# ['共通ポルトガル語（３）（中級）']
# ['共通韓国朝鮮語（７）']
# ['共通韓国朝鮮語（２１）（初級）']
# ['共通韓国朝鮮語（２５）']
# ['共通ギリシア語（１）']
# ['共通韓国朝鮮語（５）']
# ['ヒンディー語（１）']
# ['ポーランド語（１）']
# ['共通韓国朝鮮語（４）']
# ['ポーランド語（２）']
# ['セルビア・クロアチア語（２）（初級）']
# ['ヒンディー語（２）']
# ['日本語（９０）体験活動（L6-LS）']
# ['日本語（８０）ニュース・社会（L6-LS）']
# ['ポーランド語（３）']
# ['共通韓国朝鮮語（６）']
# ['セルビア・クロアチア語（１）（初級）']
# ['日本語（６０）体験活動（L4-L5）']
# ['日本語（７６）通訳技術（英日）（L7-LS）']
# ['日本語（７４）日本語のバラエティ（L6-LS）']
# ['日本語（５２）ニュース（L5-L4）']
# ['日本語（５０）歴史・社会の用語（L5-L7）']
# ['ヘブライ語（２）']
# ['セルビア・クロアチア語（３）']
# ['日本語（４８）中級総合（L4-5）']
# ['ヘブライ語（１）']
# ['タイ語（１）']
# ['台湾語（２）（初級）']
# ['ペルシャ語（２）']
# ['トルコ語（４）']
# ['トルコ語（３）モンゴル語（１）']
# ['モンゴル語（２）']
# ['日本語(７２)「比べること」による批判的読解（L6-LS）']
# ['ベトナム語（４）']
# ['広東語（１）（初級）']
# ['タイ語（２）']
# ['ペルシャ語（１）']
# ['トルコ語（２）']
# ['ベトナム語（３）']
# ['ベトナム語（１）']
# ['ベトナム語（２）']
# ['専門英語（８８）']
# ['トルコ語（１）']
# ['専門英語（８３）']
# ['専門英語（８２）']
# ['専門英語（８６）']
# ['専門英語（８７）']
# ['ヒンディー語（４）']
# ['共通日本語（４）a']
# ['専門英語（８９）']
# ['共通日本語（３）a']
# ['専門英語（７９）']
# ['専門英語（８４）']
# ['専門英語（８１）']
# ['専門英語（１０6）']
# ['専門英語（１０４）b']
# ['専門英語（１０４）a']
# ['専門英語（１０５）']
# ['専門英語（１０３）']
# ['専門英語（８５）']
# ['専門英語（１０７）']
# ['専門英語（１００）']
# ['専門英語（８０）']
# ['専門英語（１０２）']
# ['専門英語（９５）']
# ['専門英語（１０８）']
# ['専門英語（９４）']
# ['専門英語（９７）']
# ['専門英語（９８）']
# ['専門英語（９２）']
# ['専門英語（１０９）']
# ['専門英語（９６）']
# ['専門英語（９９）専門英語（９３）']
# ['教育哲学演習']
# ['教育哲学概説（教育思想論）']
# ['政治学史']
# ['日本教育史概説']
# ['共通中国語（１１）（会話）']
# ['共通中国語（１）（精読）']
# ['教育人間学概説']
# ['共通中国語（１２）（会話）']
# ['共通ロシア語（３）']
# ['共通フランス語（２）（精読）']
# ['共通中国語（５１）（精読）']
# ['共通ロシア語（２）']
# ['共通英語（７）']
# ['近現代日本教育史演習']
# ['共通英語（８）']
# ['共通英語（５）']
# ['共通英語（４）']
# ['共通英語（３）']
# ['共通英語（６）']
# ['共通英語（１）']
# ['共通英語（９）']
# ['共通フランス語（１）（精読）']
# ['共通フランス語（３）（会話）']
# ['共通英語（１０）']
# ['共通英語（２）']
# ['共通フランス語（８）（初級）']
# ['共通フランス語（２０）（初級）']
# ['共通フランス語（７）（文法）']
# ['共通ドイツ語（２）（文法）']
# ['共通フランス語（６）（作文）']
# ['共通フランス語（２１）（初級）']
# ['共通英語（教職英語コミュニケーション2）']
# ['共通フランス語（５）（作文）']
# ['共通英語（論文指導３）']
# ['共通ドイツ語（１）（文法）']
# ['共通英語（２２）']
# ['共通英語（２１）']
# ['共通英語（教職英語コミュニケーション3）']
# ['共通フランス語（２２）（初級）']
# ['共通英語（論文指導１）']
# ['共通英語（２３）']
# ['共通英語（１７）共通英語（１６）']
# ['共通英語（１９）']
# ['共通英語（１８）']
# ['共通英語（１２）']
# ['共通英語（１４）']
# ['共通フランス語（４）（会話）']
# ['共通英語（１３）']
# ['共通ロシア語（１）']
# ['共通英語（教職英語コミュニケーション1）']
# ['共通英語（２０）']
# ['共通ドイツ語（５）（論文）']
# ['共通ドイツ語（６）（初級）']
# ['共通ドイツ語（３）（精読）']
# ['共通ドイツ語（７）（初級）']
# ['共通ロシア語（２２）（初級）']
# ['共通ロシア語（２１）（初級）']
# ['共通ドイツ語（１７）（会話）']
# ['共通英語（１１）']
# ['共通ロシア語（７）']
# ['共通ドイツ語（４）（論文）']
# ['共通ロシア語（５）']
# ['共通ロシア語（８）']
# ['共通中国語（４９）（初級）']
# ['共通ドイツ語（８）（会話）']
# ['共通ロシア語（４）']
# ['共通ロシア語（２４）']
# ['共通中国語（１５）（会話）']
# ['共通ロシア語（２３）']
# ['共通中国語（１４）（精読）']
# ['共通中国語（１８）（文法）']
# ['共通中国語（１７）（精読）']
# ['共通中国語（１６）（作文）']
# ['共通中国語（５０）（初級）']
# ['共通中国語（７）（精読）']
# ['共通中国語（９）（精読）']
# ['共通中国語（４）（精読）']
# ['共通中国語（５）（会話）']
# ['共通中国語（６）（作文）']
# ['共通中国語（３）（作文）']
# ['共通ロシア語（６）']
# ['比較政治II（発展途上国の政治）']
# ['共通中国語（１３）（作文）']
# ['共通中国語（２）（会話）比較政治III（先進国の政治）']
# ['ゼミナール']
# ['共通中国語（８）（中級）']
# ['経済法']
# ['社会疫学']
# ['心の健康トピックス']
# ['生命・医療倫理Ⅱ']
# ['公衆衛生倫理']
# ['租税法']
# ['共通中国語（１０）（会話）']
# ['農業・資源経済学演習Ⅲ']
# ['小児看護学Ⅱ']
# ['農業・資源経済学演習Ⅰ']
# ['健康総合科学英語Ⅱ']
# ['卒業論文（生物・環境工学専修）']
# ['生物・環境工学実習']
# ['健康空間情報科学']
# ['生物・環境工学フィールドワーク']
# ['農業・資源経済学演習Ⅱ']
# ['環境と健康']
# ['人口学']
# ['看護学概論']
# ['農村調査概論']
# ['感染症']
# ['中国法']
# ['健康科学調査実習']
# ['疫学']
# ['東洋法制史']
# ['比較法原論']
# ['科学論文・表現技術']
# ['日本法制史']
# ['アジア政治外交史']
# ['西洋法制史（外国語科目）']
# ['アメリカ政治外交史']
# ['ローマ法']
# ['中国語学中国文学演習VI']
# ['中国語学中国文学演習V']
# ['日本近代法史']
# ['中国語学中国文学演習IV']
# ['中国語学中国文学演習III']
# ['中国語学中国文学演習II']
# ['中国語学中国文学演習VII']
# ['比較政治I（旧社会主義諸国の政治）中国語学中国文学演習VIII']
# ['中国語学中国文学演習I']
# ['解剖学']
# ['栄養学']
# ['金融法務']
# ['中国語学中国文学特殊講義XIV']
# ['金融システム論Ⅰ']
# ['労働法']
# ['国際経営Ⅰ']
# ['国際投資']
# ['少人数講義（松井 Ⅱ）']
# ['社会保障']
# ['環境政策']
# ['再生可能エネルギーと公共政策']
# ['流通と経営戦略']
# ['国際経済Ⅱ']
# ['経済データ分析']
# ['ビジネスエコノミクス']
# ['演習（大橋）']
# ['演習（岡崎）']
# ['都市経済Ⅱ']
# ['演習（藤本）']
# ['演習（粕谷）']
# ['演習（柳川）']
# ['演習（高橋伸夫）']
# ['演習（新宅）']
# ['演習（福田)']
# ['演習（馬場）']
# ['演習（神取）']
# ['演習（小野塚）']
# ['演習（谷本）']
# ['デリバティブ']
# ['演習（石原）']
# ['エネルギー政策']
# ['国際経営Ⅱ']
# ['証券投資：理論と実践']
# ['技術経営Ⅱ']
# ['金融システム論Ⅱ']
# ['保険数理Ⅱ']
# ['演習（佐口）']
# ['演習（持田）']
# ['金融政策']
# ['演習（矢坂）産業事情「自動車産業」']
# ['演習（田渕）']
# ['産業事情「ＩＴと産業界」']
# ['近代日本経済史Ⅱ']
# ['現代西洋経済史Ⅱ']
# ['演習（大森）']
# ['アジア経済史']
# ['グローバル・ベンチャリングⅠ']
# ['グローバル･ベンチャリングⅡ']
# ['流通経営']
# ['労働経済Ⅱ']
# ['金融Ⅱ']
# ['日本経済Ⅱ']
# ['不動産証券化と社会資本マネジメント']
# ['保険数理Ⅲ']
# ['物価変動の理論と実証']
# ['財政Ⅱ']
# ['上級数理統計Ⅱ']
# ['上級数理統計Ⅰ']
# ['現代日本経済史Ⅱ']
# ['ＩＣＴマネジメントⅡ']
# ['金融市場と公共政策']
# ['上級労働経済学']
# ['演習（佐藤整尚）']
# ['演習（米山）']
# ['上級世界経済Ⅰ']
# ['演習（桑嶋）']
# ['上級世界経済Ⅱ']
# ['演習（林）']
# ['演習（松島）']
# ['演習（城山）']
# ['少人数講義（松井 Ⅰ）']
# ['少人数講義(阿部 Ⅰ）']
# ['演習（高橋明彦）']
# ['少人数講義(阿部 Ⅱ）']
# ['少人数講義（久保川 Ⅱ）']
# ['演習（青木）']
# ['演習（渡辺）']
# ['金融モデルとプログラミング']
# ['金融機関のリスク管理']
# ['産業組織Ⅱ']
# ['プログラミング']
# ['経営財務Ⅰ保険数理Ⅰ']
# ['企業財務戦略']
# ['企業経済概論']
# ['企業財務']
# ['演習（山口）']
# ['金融データと金融モデル分析']
# ['少人数講義（久保川 Ⅰ）']
# ['演習（古澤）']
# ['演習（稲水）']
# ['演習（楡井）']
# ['演習（市村）']
# ['マクロ時系列の実証分析']
# ['演習（佐藤泰裕）']
# ['演習（宮尾）']
# ['演習（首藤）']
# ['演習（植田健一）']
# ['保険']
# ['少人数講義（尾山 Ⅱ）']
# ['少人数講義（尾山 Ⅰ）']
# ['上級デリバティブ']
# ['少人数講義（加藤 Ⅱ）']
# ['管理会計Ⅱ']
# ['少人数講義（加藤 Ⅰ）']
# ['数量ファイナンスⅠ']
# ['財務会計Ⅱ']
# ['数量ファイナンスⅡ']
# ['上級デリバティブ演習Ⅰ']
# ['実証ファイナンス']
# ['少人数講義（下津 Ⅱ）']
# ['少人数講義（下津 Ⅰ）']
# ['民法（１）']
# ['民法（２）']
# ['数学Ⅱ']
# ['行政法']
# ['数学Ⅰ']
# ['数量ファイナンス特論Ⅰ（証券投資：理論と実践）']
# ['アクチュアリーワークショップ Ⅰ']
# ['数量ファイナンス特論Ⅱ（ｃ++プログラミングによるデリバティブ・プライシング）']
# ['演習（中嶋）']
# ['卒業論文']
# ['アクチュアリーワークショップ Ⅱ']
# ['バイオインフォマティクス']
# ['バイオマス利用研究特論Ⅰ経営管理特論']
# ['管理会計Ⅰ']
# ['経済史Ⅱ']
# ['統計']
# ['現代西洋経済史']
# ['フードクリエーションサイエンス']
# ['経営史']
# ['フロンティアライフサイエンス']
# ['管理会計']
# ['現代日本経済史Ⅰ']
# ['労働経済']
# ['財務会計Ⅰ']
# ['産業組織Ⅰ']
# ['人口統計']
# ['現代資本主義論Ⅱ']
# ['財務会計']
# ['経済学史Ⅱ']
# ['経済統計']
# ['債券分析']
# ['計量経済学Ⅱ']
# ['金融経済学']
# ['数理統計Ⅱ']
# ['財政Ⅰ']
# ['財政']
# ['日本経済Ⅰ']
# ['金融Ⅰ']
# ['日本経済']
# ['経営科学Ⅰ']
# ['経営科学']
# ['金融']
# ['マーケティングⅠ']
# ['マーケティング']
# ['産業組織']
# ['経営史Ⅰ']
# ['労使関係']
# ['経営戦略']
# ['メカニズム・デザイン']
# ['経営管理']
# ['近代日本経済史Ⅰ']
# ['近代日本経済史']
# ['マクロ経済学Ⅱ']
# ['金融システム論']
# ['マクロ経済学マクロ経済学Ⅰ']
# ['ミクロ経済学Ⅰ']
# ['現代西洋経済史Ⅰ']
# ['日本経営史Ⅰ']
# ['経済原論Ⅰ']
# ['農業経済']
# ['経済原論']
# ['現代日本経済史']
# ['経済原論Ⅱ']
# ['ミクロ経済学Ⅱ']
# ['ミクロ経済学']
# ['国際貿易']
# ['開発経済Ⅰ']
# ['国際経済Ⅰ']
# ['都市経済Ⅰ']
# ['労働経済Ⅰ']
# ['経営戦略Ⅰ']
# ['会計']
# ['日本経営史']
# ['ファイナンス']
# ['経済史']
# ['ゲーム理論']
# ['経済史Ⅰ']
# ['統計Ⅰ']
# ['マーケットとファイナンス']
# ['統計Ⅱ']
# ['数理統計']
# ['数理統計Ⅰ']
# ['現代資本主義論Ⅰ']
# ['経営']
# ['計量経済学']
# ['計量経済学Ⅰ']
# ['経済学史']
# ['国際金融']
# ['経済学方法論']
# ['上級マクロ経済学Ⅰ']
# ['現代資本主義論']
# ['上級マクロ経済学Ⅱ']
# ['上級ミクロ経済学Ⅰ']
# ['雇用システムⅠ']
# ['経済学史Ⅰ']
# ['上級ミクロ経済学Ⅱ']
# ['経営管理Ⅰ生産システムⅠ']
# ['技術経営Ⅰ']
# ['情報経営']
# ['経営組織']
# ['上級マクロ金融']
# ['上級経済原論']
# ['技術経営']
# ['経済学のための数学']
# ['上級計量経済学Ⅱ']
# ['上級西洋経済史Ⅰ']
# ['上級計量経済学Ⅰ']
# ['フード・システムⅠ']
# ['都市経済']
# ['政治経済学']
# ['上級アジア経済史']
# ['マーケティングⅡ']
# ['日本経営史Ⅱ']
# ['上級日本経済史Ⅰ']
# ['雇用システムⅡ']
# ['経営戦略Ⅱ']
# ['応用統計']
# ['フード・システムⅡ']
# ['農業環境の放射線影響']
# ['食と健康システム演習']
# ['生産システムⅡ']
# ['食と人間']
# ['経営戦略特論']
# ['経営科学Ⅱ']
# ['上級日本経済史Ⅱ']
# ['経営史Ⅱ']
# ['国際経済論I']
# ['国際経済論II']
# ['法と経済学']
# ['労働経済I']
# ['金融論I']
# ['金融論II']
# ['イスラーム法']
# ['特別講義 現代朝鮮半島の政治']
# ['特別講義 Quantitative Social Science（外国語科目）']
# ['法哲学']
# ['医療薬学']
# ['機能生物学']
# ['特別講義 刑事政策医薬品評価科学']
# ['法社会学']
# ['薬事法・特許法']
# ['特別講義 現代アフリカの政治']
# ['薬学概論']
# ['放射化学']
# ['医薬化学III']
# ['公衆衛生学']
# ['労働経済II']
# ['製剤設計学']
# ['病理学']
# ['微生物学・化学療法学']
# ['創薬科学']
# ['薬理学II']
# ['薬物動態制御学']
# ['機能形態学']
# ['薬理学I']
# ['物理化学II']
# ['分析化学II']
# ['医薬品安全性学']
# ['分析化学I']
# ['細胞生物学']
# ['有機化学V']
# ['有機化学IV']
# ['生物統計学']
# ['発生遺伝学']
# ['分子生理化学']
# ['疾患代謝学']
# ['天然物化学']
# ['薬学特別講義']
# ['免疫学']
# ['医薬品情報学']
# ['衛生化学']
# ['特別講義 都市行政学']
# ['特別講義 国際政治経済論']
# ['特別講義 現代中国の政治']
# ['物理化学I']
# ['死生学演習I']
# ['死生学特殊講義VII']
# ['有機化学VI']
# ['物理化学III']
# ['特別講義 現代アメリカの政治']
# ['死生学特殊講義IV死生学演習II']
# ['死生学特殊講義VI']
# ['生物物理学']
# ['国際ビジネス法（外国語科目）']
# ['アジア・ビジネス法']
# ['死生学特殊講義III']
# ['社会保障法']
# ['死生学特殊講義V']
# ['会計学']
# ['死生学特殊講義I']
# ['特別講義 法医学']
# ['死生学概論']
# ['死生学特殊講義II']
# ['特別講義 医事法']
# ['統計学I']
# ['消費者法']
# ['特別講義 情報社会と法']
# ['特別講義 国際行政論']
# ['生産システムII']
# ['特別講義 現代日本外交（外国語科目）']
# ['特別講義 Introduction to Japanese law（外国語科目）']
# ['特別講義 金融法']
# ['特別講義 現代日本政治']
# ['行政法演習']
# ['学校教育学概論']
# ['身体教育学研究指導']
# ['特別講義 現代ラテンアメリカの政治']
# ['租税法演習']
# ['特別講義 Politics and Public Policy（外国語科目）']
# ['教育の疫学入門']
# ['教育の生理学']
# ['社会教育学演習IV']
# ['学校はデータでどう描けるか']
# ['公民科教育法II']
# ['社会教育論II']
# ['教育心理II']
# ['理科教育法III']
# ['数学科教育法IV']
# ['英語科教育法IV']
# ['発達心理学']
# ['社会教育学演習 III']
# ['理科教育法IV']
# ['数学科教育法III教育行政・学校経営演習I']
# ['教育社会学理論演習']
# ['教育経済学']
# ['持続可能な開発に向けた教育の取り組み']
# ['教育法']
# ['教育政策研究方法論']
# ['比較教育行政論 ―幼児教育・初等教育を中心に―']
# ['学習環境のデザイン']
# ['教育調査分析法']
# ['アイデンティティの社会学']
# ['教育行政・学校経営演習II']
# ['博物館教育論']
# ['読書教育論']
# ['フィールドワークの理論と実践']
# ['博物館学特別研究']
# ['高等教育の社会学']
# ['バリア・スタディーズ']
# ['社会教育学演習 Ⅱ']
# ['教育方法学演習Ⅱ']
# ['教育方法学演習Ⅰ']
# ['教育課程論']
# ['教育行政調査演習IV']
# ['教育行政調査演習III']
# ['情報資料論']
# ['情報組織論演習']
# ['情報サービス論']
# ['教職論']
# ['生涯学習とボランティア']
# ['図書館情報経営論']
# ['比較教育社会学論文指導']
# ['教育方法論']
# ['図書館文化史']
# ['生涯学習政策論']
# ['教育社会学調査実習Ⅳ']
# ['比較教育社会学研究指導']
# ['教育社会学調査実習II']
# ['教育社会学調査実習I']
# ['高等教育概論']
# ['比較教育学概論']
# ['教育社会学概論']
# ['教育社会学調査実習III']
# ['創造性の心理学']
# ['英語教授法・学習法概論ことばの発達心理学（学習・言語心理学）']
# ['図書館・博物館情報メディア論']
# ['博物館概論']
# ['心理学統計法 Ⅲ']
# ['学習の相談と指導Ⅲ（心理実習Ⅱ）']
# ['基礎教育学研究指導']
# ['身体表現の実践']
# ['ドラマセラピーを通した表現実践']
# ['身体教育方法論']
# ['バイオダイナミクス']
# ['安全・安心教育']
# ['質的心理学研究法 Ⅰ']
# ['教授・学習心理学演習']
# ['発達心理学演習']
# ['教授・学習心理学概論（教育・学校心理学）']
# ['学習の相談と指導Ⅰ']
# ['教育実践・政策学研究指導']
# ['心理的アセスメント']
# ['脳科学特論']
# ['ストレス・マネジメント概論（健康・医療心理学）']
# ['バリアフリー総論']
# ['機能解剖学（人体の構造と機能及び疾病）']
# ['パーソナリティの心理学（感情・人格心理学）']
# ['教育測定']
# ['ディスアビリティ・スタディーズ']
# ['心理学統計法 Ⅱ']
# ['栄養学概論']
# ['心理学統計法 Ⅰ']
# ['教育資料調査法演習']
# ['教育心理学実験演習 Ⅰ']
# ['地理歴史科教育法III']
# ['心と脳の発達']
# ['身体教育学概論II']
# ['社会科教育法IV']
# ['社会科教育法III']
# ['国語科教育法IV']
# ['教育行財政学']
# ['身体教育学概論I']
# ['情報・資料分析論演習']
# ['国語科教育法III']
# ['教育実習II']
# ['発展途上国における教育教育実習I']
# ['教職実践演習（中・高）']
# ['社会教育論I']
# ['教育相談II']
# ['特別活動の指導法']
# ['運動指導方法（夏季野外種目）']
# ['身体教育学演習Ⅰ']
# ['日本の教育研究']
# ['身体教育学演習Ⅱ']
# ['教育心理学研究指導']
# ['生徒指導・進路指導']
# ['教育心理学実験演習III']
# ['法哲学演習（外国語科目）']
# ['ドイツ法演習（外国語科目）']
# ['道徳教育法']
# ['法社会学演習（外国語科目）']
# ['身体教育学演習Ⅲ']
# ['憲法']
# ['西洋法制史演習（外国語科目）']
# ['国際法演習']
# ['教育心理学実験演習II']
# ['環境システム論']
# ['マルチエージェントシステム']
# ['社会システム工学応用']
# ['都市工学輪講第三']
# ['水環境学']
# ['地区の計画とデザイン']
# ['環境反応論']
# ['プロジェクトリスクマネジメント']
# ['経済学基礎']
# ['流体力学１']
# ['知能社会システム卒業研究']
# ['エネルギー・環境経済システム']
# ['ヒューマンモデリング']
# ['ライフサイクルの科学']
# ['都市工学輪講第二']
# ['数理演習１']
# ['産業組織論']
# ['環境調和論']
# ['災害シミュレーション工学']
# ['領域プロジェクト１Ｃ']
# ['環境公衆衛生']
# ['ライフサイクル工学地球環境工学']
# ['環境水質化学']
# ['都市環境概論']
# ['レジリエンスコロキウム']
# ['情報学概論']
# ['都市情報科学概論']
# ['環境計画基礎演習']
# ['基礎統計']
# ['地圏開発工学概論']
# ['第一原理シミュレーション技法']
# ['都市工学設計製図']
# ['放射線と環境']
# ['原子力エネルギー工学']
# ['社会調査法']
# ['量子コンピューティング']
# ['流体エネルギー資源の形成と開発']
# ['生命知コロキウム']
# ['技術プロジェクトマネジメント']
# ['コミュニケーション技法Ｃ']
# ['プログラミング応用IIＣ']
# ['プログラミング応用IＣ']
# ['応用プロジェクトＣ']
# ['基礎プロジェクトＣ']
# ['工学シミュレーション']
# ['都市工学輪講第一']
# ['システムデータ解析']
# ['核融合プラズマ科学']
# ['システムデザイン＆マネジメント卒業研究']
# ['都市工学の技術と倫理']
# ['都市工学数理']
# ['固体資源開発概論']
# ['緑地計画概論']
# ['材料力学１']
# ['都市交通論']
# ['都市デザイン概論']
# ['材料力学２']
# ['都市計画概論']
# ['物流・交通システム計画']
# ['都市居住概論']
# ['領域プロジェクト１Ｂ']
# ['安全学基礎']
# ['環境・エネルギー材料科学概論']
# ['動機付けプロジェクト環境・エネルギー概論']
# ['応用のための物理II（熱力学）']
# ['海中工学']
# ['地球科学']
# ['エネルギービーム応用工学(Energy Beam Applications and Quantum/']
# ['Relativistic Mechanics)']
# ['応用データ解析']
# ['脳神経科学']
# ['知識マネジメント']
# ['材料力学３']
# ['核融合工学・炉設計']
# ['形状モデリングと可視化']
# ['環境・エネルギープロジェクト']
# ['設計学基礎']
# ['原子炉・ビーム実習']
# ['環境・エネルギー研修']
# ['先進デザイン']
# ['応用のための物理I（古典論）']
# ['応用のための物理IV（統計力学、プラズマ）']
# ['海外インターンシップ']
# ['電磁エネルギー基礎']
# ['システム創成倫理']
# ['数理計画と最適化２']
# ['数理演習３']
# ['応用のための物理III（量子論）']
# ['システム工学基礎']
# ['数理計画と最適化１']
# ['社会システム工学基礎']
# ['社会システムと産業']
# ['力学演習２']
# ['力学演習１']
# ['ビジネス入門']
# ['物性学基礎']
# ['数理演習２']
# ['データ指向モデリング']
# ['知識と知能']
# ['量子力学']
# ['システム制御工学']
# ['システム設計科学']
# ['環境問題総論']
# ['流体力学２']
# ['環境・エネルギーの化学２']
# ['金融レジリエンス情報学地球科学２']
# ['金融市場の数理']
# ['計測工学']
# ['微分方程式の解法と可視化']
# ['システム創成学基礎']
# ['機械材料学']
# ['伝熱・熱力学(Heat Transfer)']
# ['材料力学４']
# ['環境政策論']
# ['エネルギー・資源政策論']
# ['社会のための技術']
# ['環境・エネルギーの化学１']
# ['信頼性工学']
# ['環境・エネルギー流体力学１']
# ['応用流体力学']
# ['マイニングエンジニアリング２']
# ['プロセシングエンジニアリング']
# ['都市工学実習']
# ['環境工学実験演習第二']
# ['都市工学演習Ｂ第二']
# ['環境・エネルギー流体力学２']
# ['都市工学演習Ｂ第一']
# ['環境工学実験演習第一']
# ['都市住宅論']
# ['都市工学演習Ａ第二']
# ['海洋開発工学']
# ['土地利用計画論']
# ['先端コンピューティング']
# ['廃棄物資源循環学']
# ['水質変換工学']
# ['マイニングエンジニアリング１']
# ['応用水理学']
# ['環境微生物工学']
# ['現代ツーリズム論']
# ['都市社会論']
# ['上下水道システム']
# ['都市解析']
# ['環境システム解析']
# ['都市工学演習Ｂ第三']
# ['都市工学演習Ａ第三']
# ['国際環境公衆衛生']
# ['都市開発プロジェクト論']
# ['まちづくり論国際都市地域計画論']
# ['都市計画史']
# ['産業・生活と環境技術']
# ['都市工学輪講第四']
# ['都市・まちづくりと法']
# ['都市工学演習Ａ第一']
# ['地域デザイン論']
# ['大気環境学']
# ['都市交通システム計画']
# ['都市安全計画']
# ['応用プロジェクトＡ']
# ['福祉工学']
# ['流体力学演習Ｂ']
# ['機械系応用数学']
# ['基礎プロジェクトＡ']
# ['神経と脳']
# ['機械系四力学']
# ['精密工学倫理']
# ['材料力学第二']
# ['認識行動システム論第二']
# ['システム情報工学輪講第二']
# ['システム制御２']
# ['サステナブル・マニュファクチャリング']
# ['ライフサイクル工学（精密）']
# ['数理計画と最適化I']
# ['ソフトウェア第一']
# ['システム情報工学輪講第一']
# ['システム情報工学演習第三']
# ['環境エネルギーシステム']
# ['非線形力学']
# ['機械力学']
# ['メカトロニクス']
# ['流れ学第一']
# ['材料力学第一']
# ['機械ソフトウェア演習']
# ['機械力学演習']
# ['制御工学I']
# ['画像処理工学']
# ['光工学']
# ['機構学']
# ['制御工学II']
# ['精密計測工学II']
# ['精密夏季インターンシップ生体・生命概論']
# ['熱工学第一']
# ['精密環境学']
# ['精密計測工学I']
# ['算法数理工学']
# ['回路学第二']
# ['応用空間論']
# ['技術の管理']
# ['知能機械情報学']
# ['技術とコンテンツ']
# ['生体システム工学']
# ['熱流体工学']
# ['自動車エンジンシステム']
# ['マイクロ知能機械']
# ['システム情報工学特論']
# ['計算システム論第一']
# ['機械学習の数理']
# ['機械工学少人数ゼミ']
# ['計算量理論']
# ['数理情報工学輪講']
# ['システム情報工学実験第二']
# ['計算システム論第二(３年生対象)']
# ['数理情報工学演習第二Ａ']
# ['計数工学(システム情報）卒業論文']
# ['数理情報工学実験第二']
# ['数理情報工学演習第二Ｂ']
# ['機械工学英語輪講']
# ['プログラムの数理']
# ['機械工学総合演習第二']
# ['設計工学']
# ['産業総論']
# ['精密数理II-2']
# ['産業実習']
# ['プログラミング基礎II']
# ['精密数理II-1']
# ['電気回路基礎']
# ['プログラミング基礎I']
# ['連続体力学基礎']
# ['精密工学基礎演習']
# ['生産プロセスの設計']
# ['自動車工学']
# ['機械数学演習']
# ['機械設計材料工学I']
# ['機械工学総合演習第一']
# ['計測の原理と応用']
# ['生体計測論']
# ['生産システム']
# ['生産の技術']
# ['計数工学特別講義']
# ['機械振動学基礎']
# ['生体情報論']
# ['計算システム論第二(４年生対象)']
# ['有限要素法']
# ['熱工学第二']
# ['振動・波動学']
# ['生体機械工学']
# ['機械分子工学第一']
# ['設計演習II']
# ['流れ学第二']
# ['機械分子工学第二']
# ['計数工学（数理情報）卒業論文']
# ['精密数理I-2']
# ['計測と加工の基礎']
# ['医療工学']
# ['信号処理工学']
# ['技術者倫理']
# ['ロボットシステム']
# ['ロボットインテリジェンス']
# ['確率・統計']
# ['設計演習I']
# ['ヒューマン・インタフェース']
# ['ロボットコントロール']
# ['ロボティクスII（Robotics II）']
# ['パターン情報学']
# ['システム制御１']
# ['機械系数値解析法']
# ['精密数理I-1']
# ['精密工学卒業研究']
# ['英語プレゼンテーションＢ']
# ['英語プレゼンテーションＡ']
# ['ロボティクスI（Robotics I）']
# ['アクチュエータ工学']
# ['プログラミング応用IＢ']
# ['センサ工学']
# ['生体工学インターンシップB2']
# ['インターンシップB1']
# ['プログラミング応用IIＢ']
# ['メカトロニクスシステム設計']
# ['システムデザイン＆マネジメント特別プロジェクト２']
# ['応用プロジェクトＢ']
# ['ロボット工学']
# ['プログラミング応用II']
# ['コミュニケーション技法Ｂ']
# ['プログラミング応用I']
# ['システムデザイン＆マネジメント特別プロジェクト１']
# ['材料工学II']
# ['精密機構学']
# ['基礎プロジェクトＢ']
# ['電子回路工学']
# ['精密振動学']
# ['精密工学生産現場実習']
# ['機械運動学']
# ['精密工学輪講・工場見学']
# ['連続体力学応用']
# ['シミュレーション演習']
# ['マイクロナノ加工学']
# ['生産システム管理']
# ['精密加工学II']
# ['環境・エネルギー卒業研究']
# ['精密工学実践演習']
# ['コミュニケーション技法Ａ２']
# ['領域プロジェクト１Ａ']
# ['精密加工学I']
# ['設計学']
# ['流体力学演習Ａ２']
# ['プログラミング応用IＡ']
# ['精密工学特別講義']
# ['夏季インターンシップＡ']
# ['コミュニケーション技法Ａ１']
# ['流体力学演習Ａ１']
# ['プログラミング応用IIＡ']
# ['人工物工学']
# ['回路学第一']
# ['計数工学実験']
# ['デバイス材料工学']
# ['薄膜プロセス工学']
# ['システム情報工学設計演習数理計画法']
# ['材料量子力学']
# ['冬季日本語特別集中科目６（A1A2開講）']
# ['日本語初級３（S1S2開講）']
# ['日本語初級３（A1A2開講）']
# ['応用マテリアル工学']
# ['マテリアル工学演習']
# ['マテリアル工学基礎及び演習II']
# ['日本語インテンシブ初級II AM（A1A2開講）']
# ['メカトロニクス設計演習']
# ['夏季日本語特別集中科目３（S1S2開講）']
# ['マテリアル工学基礎及び演習I']
# ['日本語上級 日本組織事情Ｂ（A1A2開講）']
# ['夏季日本語特別集中科目２（S1S2開講）']
# ['日本語上級 文章（A1A2開講）']
# ['夏季日本語特別集中科目１（S1S2開講）']
# ['日本語上級 読解（A1A2開講）']
# ['日本語上級 日本組織事情Ａ（A1A2開講）']
# ['マテリアル設計学']
# ['日本語上級 読解（S1S2開講）']
# ['日本語上級 日本組織事情Ａ（S1S2開講）']
# ['生産プロセス工学']
# ['日本語中級２ 読解（S1S2開講）']
# ['マテリアル工学卒業論文']
# ['マテリアル工学卒業論文輪講']
# ['日本語中級２ 聴解（S1S2開講）']
# ['日本語中級２ 読解（A1A2開講）']
# ['日本語中級２ 総合（A1A2開講）']
# ['日本語中級１ 文章（A1A2開講）']
# ['日本語上級 文章（S1S2開講）']
# ['日本語中級１ 専門読解（A1A2開講）']
# ['日本語中級１ 会話（A1A2開講）']
# ['日本語中級２ 会話（S1S2開講）']
# ['日本語中級１ 文章（S1S2開講）']
# ['日本語中級１ 聴解（A1A2開講）']
# ['日本語中級２ 聴解（A1A2開講）']
# ['日本語中級１ 総合（A1A2開講）']
# ['日本語中級１ 専門読解（S1S2開講）']
# ['日本語初級４（S1S2開講）']
# ['日本語中級１ 会話（S1S2開講）']
# ['分子細胞生物学']
# ['日本語初級４（A1A2開講）']
# ['日本語中級１ 総合（S1S2開講）日本語中級３ 会話（S1S2開講）']
# ['日本語中級３ 会話（A1A2開講）']
# ['日本語中級３ 聴解（S1S2開講）']
# ['日本語中級３ 総合（S1S2開講）']
# ['日本語中級３ 総合（A1A2開講）']
# ['日本語中級２ 専門語彙・漢字（A1A2開講）']
# ['日本語中級２ 専門語彙・漢字（S1S2開講）']
# ['日本語中級２ 文章（S1S2開講）']
# ['日本語中級２ 総合（S1S2開講）']
# ['日本語中級１ 聴解（S1S2開講）']
# ['日本語初級２（A1A2開講）']
# ['日本語インテンシブ初級II AM（S1S2開講）']
# ['日本語中級３ 聴解（A1A2開講）']
# ['日本語初級１（S1S2開講）']
# ['日本語初級２（S1S2開講）']
# ['日本語インテンシブ初級I AM（A1A2開講）']
# ['日本語初級１（A1A2開講）']
# ['日本語上級 聴解（A1A2開講）']
# ['日本語上級 会話（A1A2開講）']
# ['日本語上級 聴解（S1S2開講）']
# ['日本語上級 総合（S1S2開講）']
# ['日本語中級３ 文章（A1A2開講）']
# ['日本語中級３ 文章（S1S2開講）']
# ['日本語上級 総合（A1A2開講）']
# ['日本語中級３ 専門読解（A1A2開講）']
# ['日本語インテンシブ初級I AM（S1S2開講）']
# ['日本語中級２ 文章（A1A2開講）']
# ['冬季日本語特別集中科目２（A1A2開講）']
# ['冬季日本語特別集中科目１（A1A2開講）']
# ['日本語中級３ 専門読解（S1S2開講）']
# ['冬季日本語特別集中科目５（A1A2開講）']
# ['夏季日本語特別集中科目４（S1S2開講）']
# ['冬季日本語特別集中科目３（A1A2開講）']
# ['夏季日本語特別集中科目５（S1S2開講）']
# ['応用医療材料学']
# ['夏季日本語特別集中科目６（S1S2開講）']
# ['応用半導体プロセス学']
# ['日本語中級２ 会話（A1A2開講）']
# ['応用光デバイス材料学']
# ['応用複合材料学']
# ['マテリアル工学輪講']
# ['マテリアル環境学']
# ['創造設計演習応用鉄鋼材料学']
# ['マテリアル工学倫理']
# ['冬季日本語特別集中科目４（A1A2開講）']
# ['表面・界面化学']
# ['数学及び演習']
# ['固体物性学']
# ['材料強度学']
# ['マテリアル工学実験I']
# ['応用バイオデバイス材料学']
# ['組織形成論']
# ['応用熱力学']
# ['マテリアル工学実地演習第二']
# ['日本語上級 会話（S1S2開講）']
# ['材料力学II']
# ['マテリアル工学実地演習第一']
# ['マテリアルシミュレーションII']
# ['マテリアルシミュレーションI']
# ['材料力学I']
# ['マテリアル工学実験II']
# ['材料電気化学']
# ['材料相平衡論']
# ['材料速度論']
# ['材料反応工学']
# ['材料結晶学']
# ['マテリアル工学自由研究']
# ['材料統計力学']
# ['有機材料化学']
# ['システム情報工学演習第二']
# ['無機材料化学']
# ['信号処理論第二']
# ['認識行動システム論第一']
# ['マテリアル工学概論']
# ['信号処理論第一']
# ['基礎熱力学']
# ['センサ・アクチュエータ工学']
# ['セラミック材料学']
# ['高分子科学II']
# ['マテリアル環境工学概論']
# ['工学倫理（計数）']
# ['半導体物性学']
# ['制御論第二']
# ['高分子科学I']
# ['材料信頼性学数理情報工学演習第一Ｃ']
# ['数理情報工学演習第一Ｂ']
# ['システム情報工学実験第一']
# ['計数工学プログラミング演習']
# ['システム情報工学演習第一']
# ['計数工学実地演習']
# ['応用統計学']
# ['確率数理工学']
# ['数理情報工学演習第一Ａ']
# ['解析数理工学']
# ['制御論第一']
# ['金属材料学']
# ['知能ソフトウェア演習']
# ['認識行動システムの基礎']
# ['幾何数理工学']
# ['代数数理工学']
# ['ソフトウェア第二']
# ['ロボットシステム演習']
# ['数理情報工学実験第一']
# ['応用電気工学']
# ['計算論']
# ['電気機器学基礎']
# ['電子基礎物理']
# ['メディアコンテンツ特別講義II']
# ['電気機器設計法演習']
# ['伝熱工学']
# ['電力システム工学第二']
# ['応用物性工学']
# ['分散システム']
# ['情報工学概論（インターネット工学）']
# ['電気工学実験大要Ｂ']
# ['数学２Ｇ']
# ['数学２Ｄ(物工・計数)']
# ['数学２Ｄ(電気電子)']
# ['電気磁気学II']
# ['ネットワーク工学概論']
# ['ハードウエア設計論']
# ['数学２Ｂ']
# ['電磁界応用工学']
# ['電力システム工学第一']
# ['数学２Ｆ']
# ['システム数理工学']
# ['エネルギー物質化学創造的ものづくりプロジェクトII']
# ['工学とデザイン']
# ['生態学・生態工学']
# ['多文化理解プロジェクト']
# ['創造的ものづくりプロジェクトIII']
# ['エネルギーと社会']
# ['コンピュータアーキテクチャ']
# ['ＶＬＳＩ工学基礎']
# ['電子回路II']
# ['光電子デバイス']
# ['アカデミック・プレゼンテーション']
# ['アントレプレナーシップIII']
# ['アカデミック・ライティング']
# ['創造的ものづくりプロジェクトI']
# ['生命科学概論(マテ･応化･化シス)']
# ['生命科学概論(電気系･物工･計数)']
# ['技術論']
# ['アントレプレナーシップII']
# ['光電子工学I']
# ['アントレプレナーシップI']
# ['数理手法VII']
# ['電気工学通論第一']
# ['情報工学概論（アルゴリズムとデータ構造）']
# ['経済工学II']
# ['特許法']
# ['経済工学I']
# ['国際経済学']
# ['職業指導']
# ['数学及力学演習Ｉ']
# ['数理手法II']
# ['数理手法IV']
# ['分離工学II']
# ['電気工学通論第二']
# ['数理手法III']
# ['反応工学II']
# ['化学システム工学輪講']
# ['物理化学及び演習II']
# ['プロセスシステム工学I']
# ['エネルギー工学']
# ['触媒工学']
# ['制御工学第二']
# ['エネルギー変換工学']
# ['環境システム工学I制御工学第一']
# ['パワーエレクトロニクス']
# ['電気電子情報工学倫理']
# ['プロセスシステム工学II']
# ['電子物性基礎']
# ['電子量子力学I']
# ['グローバルシステム工学']
# ['モーションコントロール']
# ['設計・機械力学・機構通論']
# ['電子量子力学II']
# ['電子物性第二']
# ['環境電気工学']
# ['環境学特別講義']
# ['統計的機械学習']
# ['化学流体力学']
# ['半導体物性工学']
# ['数学３']
# ['環境システム工学概論']
# ['数理手法VI']
# ['スパコンプログラミング(１)(A1A2開講)']
# ['先端技術と社会特別講義II（偶数年開講）']
# ['スパコンプログラミング(１)(S1S2開講)']
# ['情報通信理論']
# ['ソフトウェアII']
# ['ソフトウェアI']
# ['プログラミング基礎演習']
# ['ディジタル回路']
# ['電気回路理論第一']
# ['電子物性第一']
# ['電気電子計測']
# ['電気磁気学I']
# ['信号解析基礎']
# ['脳科学入門']
# ['プロセス設計及び演習']
# ['電子デバイス基礎']
# ['卒業論文(化学システム工学）']
# ['化学工学及び演習II']
# ['半導体デバイス工学']
# ['システム安全工学']
# ['プラズマ理工学']
# ['環境システム工学II']
# ['電磁波工学']
# ['電気電子情報実験・演習第二電気機器ＣＡＤ演習']
# ['化学システム工学基礎論']
# ['電気回路理論第二']
# ['言語・音声情報処理']
# ['電気電子数学演習']
# ['電気電子情報工学実習']
# ['映像メディア工学']
# ['電気電子情報実験・演習第一']
# ['電子情報機器学']
# ['オペレーティングシステム']
# ['人工知能']
# ['無線通信応用工学']
# ['アルゴリズム']
# ['電気自動車工学']
# ['情報通信工学']
# ['ヒューマンインターフェース工学']
# ['電子材料プロセス']
# ['宇宙電気電子システム工学']
# ['電気系特別講義第一']
# ['バイオエレクトロニクス']
# ['ワイヤレスエレクトロニクス']
# ['電気材料基礎論']
# ['日本語入門（S2開講）']
# ['メディアコンテンツ特別講義I']
# ['情報セキュリティ']
# ['通信網工学']
# ['ＶＬＳＩ設計工学']
# ['日本語入門（A2開講）']
# ['高電圧工学']
# ['光電子工学II']
# ['プログラミング言語']
# ['ＶＬＳＩアーキテクチャ']
# ['数学及力学演習Ｇ']
# ['数学１Ａ']
# ['電子回路I']
# ['計測通論Ｃ']
# ['化学・生命系実験及演習']
# ['化学反応論I']
# ['空間情報学実習']
# ['高分子化学II']
# ['統計解析']
# ['計算地震工学(E)']
# ['構造設計特論(E)振動・制御・計測(E)']
# ['社会技術としての化学技術']
# ['数学及力学演習Ｂ']
# ['基礎プロジェクトI']
# ['沿岸環境学']
# ['空間情報学I']
# ['構造物の計画と設計']
# ['空間情報学II']
# ['信頼性設計とリスク分析']
# ['海岸工学']
# ['コンクリート工学']
# ['材料の力学']
# ['地盤の工学']
# ['量子化学I']
# ['企業と技術経営']
# ['物性論I']
# ['水文学']
# ['社会基盤イノベーション(E)']
# ['電気工学大要第一']
# ['国際プロジェクトのケーススタディ(E)']
# ['基礎プロジェクトII']
# ['河川流域の環境とその再生']
# ['途上国プロジェクト特論']
# ['法学基礎']
# ['地球環境学']
# ['エネルギー開発の実践']
# ['社会基盤学倫理']
# ['統計解析手法']
# ['国際コミュニケーションの基礎 I']
# ['国際コミュニケーションの基礎 II']
# ['地盤工学応用特論(E)']
# ['シビルエンジニアの活躍する世界']
# ['風と構造物(E)']
# ['景観学']
# ['土地学']
# ['国際プロジェクト序論']
# ['プロジェクトマネジメント']
# ['社会基盤史']
# ['導入プロジェクト']
# ['社会基盤のための経済・財務学(E)']
# ['水圏デザイン基礎']
# ['基礎プロジェクトIII']
# ['基盤技術設計論II基盤技術設計論I']
# ['水理学']
# ['社会基盤技術の実装戦略']
# ['社会基盤学序論']
# ['生命化学I']
# ['生命化学II']
# ['自然災害と都市防災']
# ['コンピュータ科学']
# ['化学工学I']
# ['コンピュータ及び演習']
# ['少人数セミナーI']
# ['応用プロジェクトIV']
# ['少人数セミナーII']
# ['応用プロジェクトIII']
# ['基礎プロジェクトIV']
# ['応用プロジェクトII']
# ['交通学']
# ['開発とインフラ']
# ['基礎情報学']
# ['都市学']
# ['技術移転と政策']
# ['応用プロジェクトI']
# ['応用プロジェクトV']
# ['社会基盤プロジェクト(卒研)']
# ['バイオテクノロジーII']
# ['マネジメント原論']
# ['総合プロジェクト演習']
# ['有機化学実験及演習']
# ['化学・生命研究倫理']
# ['公共経営学']
# ['化学工業実地演習']
# ['化学反応論II']
# ['分子集合体化学']
# ['ケミカル・バイオ・インダストリー']
# ['分離工学I']
# ['社会基盤学実習']
# ['分析化学実験及演習']
# ['反応工学I']
# ['量子化学II']
# ['高分子化学I']
# ['生命工学実験及演習']
# ['化学工学及び演習I']
# ['物理化学実験及演習化学工学実験及演習']
# ['計測通論Ｂ']
# ['構造解析法']
# ['数理手法V']
# ['数理手法I']
# ['計測通論Ａ']
# ['数学１Ｅ']
# ['数学１Ｄ']
# ['化学工学II']
# ['コンピュータ化学演習']
# ['数学１Ｂ']
# ['バイオテクノロジーI']
# ['建築構法特論']
# ['建築構造演習']
# ['鉄筋コンクリート構造']
# ['化学生命工学最前線']
# ['建築設計基礎第二']
# ['物理工学実験第二']
# ['環境工学概論']
# ['計算科学概論']
# ['建築防火工学']
# ['建築設計基礎第一']
# ['鉄骨構造演習']
# ['物理工学実験法']
# ['統計力学第二']
# ['鉄骨構造']
# ['物理実験の基礎第二']
# ['光学']
# ['数値解析']
# ['電磁気学第二']
# ['物理数学']
# ['物理工学工学倫理']
# ['回路とシステムの基礎']
# ['量子力学第一']
# ['物理工学基礎演習']
# ['固体物理第三']
# ['造形第五']
# ['固体物理第四']
# ['半導体概論']
# ['統計力学第一']
# ['固体物理第二']
# ['固体物理第一']
# ['量子力学第二連続体の力学']
# ['物理実験の基礎第一']
# ['建築基礎構造']
# ['分子エレクトロニクス']
# ['統計力学第三']
# ['数学演習']
# ['情報理論']
# ['量子情報']
# ['応用音響学']
# ['統計熱力学']
# ['卒業制作']
# ['有機物性論']
# ['エネルギー化学I']
# ['応用化学基礎論']
# ['造形第一']
# ['卒業考査']
# ['量子力学第三']
# ['鉄筋コンクリート構造演習']
# ['建築総合演習']
# ['建築法規']
# ['建築弾性学']
# ['無機化学III']
# ['建築材料学概論']
# ['建築構法概論']
# ['ナノ科学']
# ['現代物質構造論']
# ['建築熱環境']
# ['荷重外力論第一']
# ['複雑流体の物理']
# ['物理工学演習第二']
# ['表面物理']
# ['建築構造解析第一']
# ['物理工学実験第一']
# ['物理工学輪講第一']
# ['物理工学演習第一']
# ['建築計画第三']
# ['建築設計理論第四']
# ['建築構造計画概論']
# ['建築計画第一']
# ['造形第二']
# ['建築計画第二']
# ['建築設計製図第二']
# ['建築倫理ソフトマター物理']
# ['都市建築史概論']
# ['物理工学卒業論文']
# ['建築計画第四']
# ['物理工学輪講第三']
# ['建築設計製図第一']
# ['物理工学特別輪講']
# ['環境・設備演習']
# ['建築設備第一']
# ['日本建築史']
# ['建築環境デザイン論']
# ['物理工学特別講義第五']
# ['西洋建築史']
# ['建築設計製図第六']
# ['建築空気環境・水環境']
# ['建築音環境']
# ['建築設計製図第四']
# ['建築耐震構造']
# ['物理工学輪講第二']
# ['建築構造解析第二']
# ['荷重外力論第二']
# ['建築塑性学']
# ['建築設備第三']
# ['建築光環境・視環境']
# ['建築構造解析第三']
# ['建築設計製図第三']
# ['溶接工学']
# ['建築設備第二']
# ['建築構法計画']
# ['建築材料演習']
# ['建築材料計画']
# ['建築設計理論第一']
# ['基礎流体力学']
# ['造形第六']
# ['建築設計製図第五']
# ['社会技術論']
# ['卒業論文(化学生命工学）']
# ['建築設計理論第二']
# ['生命化学演習']
# ['建築施工']
# ['有機・高分子演習']
# ['分子生物学I']
# ['数理分析の基礎分子生物学III']
# ['構造の力学']
# ['建築材料科学']
# ['近代都市建築史']
# ['建築設計製図第七']
# ['分子生物学II']
# ['造形第四']
# ['建築設計理論第三']
# ['建築生産マネジメント概論']
# ['フロンティア化学']
# ['造形第三']
# ['エネルギー化学II']
# ['応用化学基礎論II']
# ['応用化学演習']
# ['建築水理学']
# ['物性論II']
# ['卒業論文(応用化学）']
# ['分析化学III']
# ['弾性力学第一']
# ['ガスタービン第二']
# ['母性看護学']
# ['弾性力学第二']
# ['宇宙機制御工学']
# ['機械振動論']
# ['看護支援技術論']
# ['生命科学・ゲノム学Ⅱ']
# ['疾病論']
# ['公共健康科学演習Ⅰ']
# ['健康教育（職域・地域）']
# ['生命・医療倫理Ⅰ']
# ['チベット語I']
# ['航空宇宙材料']
# ['生物統計学実習']
# ['生命科学・ゲノム学Ⅰ']
# ['チベット語II']
# ['ラテン語中級I']
# ['ラテン語中級II']
# ['中国語後期VI']
# ['中国語後期VII']
# ['中国語後期V']
# ['原典を読むII']
# ['日本手話I']
# ['日本住宅建築史ラテン語初級I']
# ['ペルシア語II']
# ['ギリシャ語I']
# ['日本手話II']
# ['最適化手法']
# ['ギリシャ語II']
# ['原典を読むIII']
# ['英語で学ぶ専門科目（航空工学）']
# ['航空機運航管理']
# ['宇宙科学']
# ['航空機設計法第三']
# ['ラテン語初級II']
# ['航空機制御工学']
# ['ペルシア語I']
# ['航空宇宙工学特別講義']
# ['航空機設計法第二']
# ['人類遺伝学Ⅰ']
# ['社会と健康']
# ['健康総合科学概論']
# ['基礎数理']
# ['健康総合科学英語Ⅰ']
# ['国際保健学']
# ['人類遺伝学Ⅱ']
# ['アラビア語II']
# ['基礎生命科学']
# ['免疫と生態防御']
# ['病態疾患論']
# ['薬理学・毒性学']
# ['原典を読むI']
# ['生命科学実習Ⅰ']
# ['生理学']
# ['医学データの統計解析']
# ['疫学論文の読み方と書き方']
# ['母子保健学']
# ['医学データの統計解析実習']
# ['電磁気学第一']
# ['生命環境科学のトピックス']
# ['生命環境科学演習']
# ['生命科学実習Ⅱ']
# ['在宅看護学実習']
# ['心の健康科学']
# ['健康支援実習']
# ['人類生態学健康行動の理論と科学']
# ['基礎看護学実習']
# ['看護管理学']
# ['家族と健康']
# ['基礎看護学Ⅰ']
# ['急性期看護学実習']
# ['看護管理学実習']
# ['公共健康科学統合講義Ⅱ']
# ['在宅看護論']
# ['精神保健学実習']
# ['公共健康科学演習Ⅱ']
# ['航空宇宙学製図第二']
# ['航空宇宙推進学第一']
# ['学校保健学']
# ['航空機力学第一']
# ['航空宇宙情報システム学第一']
# ['公共健康科学統合講義Ⅰ']
# ['宇宙工学入門']
# ['基礎材料力学']
# ['基礎看護学Ⅱ']
# ['看護理工学']
# ['航空宇宙学製図第一']
# ['空気力学第一']
# ['環境人間工学']
# ['医療人類学']
# ['老年看護学']
# ['発生発達学']
# ['解剖示説']
# ['母性看護学実習']
# ['宇宙軌道力学']
# ['航空宇宙情報システム学第三']
# ['数値構造解析']
# ['慢性期看護学実習']
# ['構造振動論']
# ['航空宇宙学倫理']
# ['航空宇宙推進学第四']
# ['宇宙推進工学第一']
# ['応用数理']
# ['老年看護学実習']
# ['航空宇宙推進学第三']
# ['成人看護学']
# ['ヘルスコミュニケーション学']
# ['精神看護学実習精神看護学']
# ['統合実践実習']
# ['ガスタービン第一']
# ['航空宇宙学実地演習']
# ['臨床・疫学研究の実例']
# ['航空宇宙推進学演習']
# ['社会福祉・社会保障論']
# ['航空宇宙推進学実験']
# ['航空宇宙推進学製図']
# ['小児看護学実習Ⅰ']
# ['航空宇宙学基礎設計']
# ['航空機構造力学第二']
# ['空気力学第五']
# ['航空宇宙システム学製図']
# ['航空宇宙システム学実験']
# ['ロケットエンジン構造及設計']
# ['ジェットエンジン構造及設計']
# ['小児看護学実習Ⅱ']
# ['小児看護学Ⅰ']
# ['宇宙推進工学第二']
# ['航空宇宙推進学第五']
# ['航空宇宙推進学計画及製図']
# ['空気力学第二Ｄ']
# ['空気力学第二Ｂ']
# ['空気力学第四']
# ['航空宇宙システム学計画及製図']
# ['空気力学第二Ｃ']
# ['空気力学第二Ａ']
# ['航空機設計法第一']
# ['宇宙工学演習']
# ['航空宇宙構造力学']
# ['宇宙工学通論']
# ['航空機力学第二']
# ['航空宇宙自動制御第二']
# ['航空宇宙自動制御第一']
# ['ジェットエンジン']
# ['航空機力学第三']
# ['航空機構造力学第一']
# ['航空宇宙情報システム学第二']
# ['基礎振動論']
# ['航空技術イノベーション概論']
# ['空気力学第三']
# ['アラビア語I地理学I']
# ['英語後期VIII']
# ['航空宇宙推進学第二']
# ['韓国朝鮮文化演習III']
# ['文化人類学']
# ['情報メディア論I']
# ['ロシア語初級I']
# ['文化資源学演習I']
# ['情報メディア論II']
# ['社会学演習I']
# ['社会学演習II']
# ['フランス語後期II']
# ['中国語後期I']
# ['社会学演習III']
# ['人文情報学特殊講義ＩＶ']
# ['社会学演習XV']
# ['人文情報学特殊講義II']
# ['文化資源学特殊講義IV']
# ['人文情報学特殊講義III']
# ['人文情報学概論I']
# ['人文情報学特殊講義I']
# ['中国語後期II']
# ['社会学演習XXII']
# ['卒業論文（卒業論文指導を含む）']
# ['社会学演習IV']
# ['博物館展示論']
# ['博物館空間表現実習']
# ['社会学演習XXI']
# ['文化施設経営論']
# ['文化資源学特殊講義II']
# ['文化資源学特殊講義III']
# ['社会学演習XIV']
# ['社会学演習XII']
# ['社会学演習X']
# ['社会学演習XIII']
# ['文化資源学特殊講義V']
# ['社会学演習IX']
# ['文化資源学入門I']
# ['文化資源学特殊講義I']
# ['社会学演習VI']
# ['社会学特殊講義XVI']
# ['社会学特殊講義XIV']
# ['社会学特殊講義XIII社会学演習VIII']
# ['社会学特殊講義XII']
# ['文化資源学入門II']
# ['社会学特殊講義XV']
# ['社会学特殊講義XI']
# ['社会学演習VII']
# ['文化環境学特殊講義II']
# ['社会学演習V']
# ['文化環境学特殊講義I']
# ['文化環境学特殊講義III']
# ['社会学特殊講義X']
# ['文化資源学特殊講義XIII']
# ['文化交流演習III']
# ['文化資源学特殊講義XI']
# ['文化資源学特殊講義XII']
# ['文化交流演習II']
# ['人文情報学概論II']
# ['文化環境学特殊講義IV']
# ['文化資源学特殊講義VI']
# ['韓国朝鮮文化演習II']
# ['文化資源学特殊講義XV']
# ['文化交流演習IV']
# ['文化資源学特殊講義X']
# ['韓国朝鮮文化演習I']
# ['韓国朝鮮文化特殊講義VI']
# ['韓国朝鮮文化特殊講義VII']
# ['韓国朝鮮文化特殊講義IV']
# ['韓国朝鮮文化特殊講義II']
# ['フランス語後期I']
# ['フランス語前期II']
# ['韓国朝鮮文化特殊講義III']
# ['韓国朝鮮文化特殊講義V']
# ['ドイツ語後期II']
# ['文化資源学特殊講義VII']
# ['文化資源学特殊講義IX']
# ['韓国朝鮮文化特殊講義I']
# ['文化資源学特殊講義VIII']
# ['英語後期X']
# ['博物館資料論（美術工芸品）']
# ['ドイツ語前期II']
# ['精神医学']
# ['フランス語前期I']
# ['英語後期IX地理学II']
# ['電算機応用II']
# ['漢文学']
# ['文化交流特殊講義IV']
# ['ドイツ語前期I']
# ['電算機応用I']
# ['ドイツ語後期I']
# ['文化交流演習I']
# ['韓国朝鮮文化演習V']
# ['文化交流特殊講義II']
# ['文化交流特殊講義III']
# ['韓国朝鮮文化演習IV']
# ['文化交流特殊講義I']
# ['中国語前期II']
# ['中国語前期I']
# ['日本の思想と宗教']
# ['韓国朝鮮文化演習VIII']
# ['韓国朝鮮文化演習VI']
# ['博物館学実習C']
# ['学外館園実習']
# ['近代日本の文化と社会']
# ['英語後期V']
# ['博物館学実習A']
# ['英語後期II']
# ['英語後期III']
# ['英語後期VII']
# ['英語後期IV']
# ['中国語後期IV']
# ['中国語後期III']
# ['韓国朝鮮語初級I']
# ['英語後期I']
# ['ヒンディー語I']
# ['英語後期VI']
# ['博物館資料論（歴史資料）']
# ['韓国朝鮮語初級II']
# ['韓国朝鮮文化演習VII']
# ['韓国朝鮮語中級']
# ['ポルトガル語II']
# ['スペイン語中級I']
# ['ヒンディー語II']
# ['イタリア語中級II']
# ['イタリア語初級II']
# ['ポルトガル語Iロシア語中級II']
# ['ロシア語中級I']
# ['イタリア語初級I']
# ['ロシア語初級II']
# ['イタリア語中級I']
# ['スペイン語初級I']
# ['スペイン語中級II']
# ['スペイン語初級II']
# ['社会学特殊講義IX']
# ['社会学特殊講義VIII']
# ['近代文学特殊講義ＩＩ']
# ['現代文芸論演習ＩＶ']
# ['近代文学特殊講義I']
# ['心理学特殊講義I']
# ['社会心理学統計II']
# ['心理学特殊講義X']
# ['西洋古典学演習II']
# ['西洋古典学演習I']
# ['近代語近代文学演習Ｉ']
# ['スラヴ語学スラヴ文学特殊講義VI']
# ['心理学演習VIII']
# ['社会学史概説']
# ['フランス語学フランス文学演習X']
# ['フランス語学フランス文学演習II']
# ['フランス語学フランス文学特殊講義VI']
# ['フランス語学フランス文学特殊講義V']
# ['フランス語学フランス文学演習IX']
# ['フランス語学フランス文学特殊講義ＩＩＩ']
# ['フランス語学フランス文学特殊講義II']
# ['フランス語学フランス文学演習I']
# ['フランス語圏言語文化']
# ['スラヴ語学スラヴ文学演習V']
# ['フランス語学フランス文学特殊講義I']
# ['スラヴ語学スラヴ文学演習III']
# ['フランス語学フランス文学特殊講義VII']
# ['スラヴ語学スラヴ文学演習IV']
# ['スラヴ語学スラヴ文学演習II']
# ['イタリア語学イタリア文学特殊講義V']
# ['フランス語学フランス文学演習VIII']
# ['スラヴ語学スラヴ文学演習I']
# ['イタリア語学イタリア文学特殊講義IV']
# ['イタリア語学イタリア文学特殊講義I']
# ['南欧語圏言語文化特殊講義Iフランス文学史概説']
# ['イタリア語学イタリア文学特殊講義III']
# ['スラヴ語学スラヴ文学演習VI']
# ['イタリア語学概論I']
# ['イタリア語学概論II']
# ['スラヴ語学スラヴ文学特殊講義VIII']
# ['スラヴ語学スラヴ文学特殊講義VII']
# ['イタリア語学イタリア文学特殊講義II']
# ['スラヴ語学スラヴ文学特殊講義IX']
# ['イタリア文学史概説II']
# ['フランス語学フランス文学演習VI']
# ['イタリア文学史概説I']
# ['フランス語学フランス文学演習IV']
# ['スラヴ語学スラヴ文学特殊講義V']
# ['スラヴ語学スラヴ文学特殊講義III']
# ['フランス語学フランス文学演習VII']
# ['フランス語学フランス文学演習V']
# ['フランス語学フランス文学特殊講義IV']
# ['スラヴ語圏言語文化I']
# ['スラヴ文学史概説']
# ['スラヴ語圏言語文化II']
# ['スラヴ語学スラヴ文学特殊講義IV']
# ['フランス語学フランス文学演習III']
# ['スラヴ語学スラヴ文学特殊講義I']
# ['イタリア語学イタリア文学演習V']
# ['スラヴ語学スラヴ文学特殊講義II']
# ['イタリア語学イタリア文学演習VI']
# ['スラヴ語学概論']
# ['イタリア語学イタリア文学演習III']
# ['イタリア語学イタリア文学特殊講義VII']
# ['イタリア語学イタリア文学演習II']
# ['西洋古典学特殊講義IV']
# ['イタリア語学イタリア文学演習IV']
# ['イタリア語学イタリア文学特殊講義VI']
# ['西洋古典学特殊講義III']
# ['西洋古典学特殊講義II']
# ['南欧語圏言語文化演習II']
# ['南欧語圏言語文化演習I']
# ['イタリア語学イタリア文学演習I']
# ['西洋古典学特殊講義V']
# ['心理学統計III']
# ['心理学統計I']
# ['心理学研究法近代語近代文学演習ＩＩ']
# ['心理学統計II']
# ['西洋古典学特殊講義I']
# ['心理学概論I']
# ['西洋古典学演習V']
# ['心理学特殊講義VIII']
# ['心理学特殊講義IX']
# ['西洋古典学演習III']
# ['心理学特殊講義VII']
# ['心理学特殊講義V']
# ['心理学特殊講義II']
# ['心理学特殊講義III']
# ['心理学特殊講義IV']
# ['社会心理学統計I']
# ['西洋古典学演習IV']
# ['社会心理学概論II']
# ['心理学実験演習V']
# ['心理学実験演習III']
# ['心理学概論II']
# ['近代語学特殊講義ＩＶ']
# ['心理学実験演習II']
# ['心理学実験演習I']
# ['近代語学特殊講義II']
# ['近代語学特殊講義I']
# ['現代文芸論概説II']
# ['現代文芸論概説I']
# ['近代語学特殊講義III']
# ['心理学演習VI']
# ['心理学特殊講義VI']
# ['心理学演習V']
# ['心理学演習III']
# ['比較文学概論']
# ['心理学演習IV']
# ['心理学特殊講義XII']
# ['心理学演習II']
# ['現代文芸論演習ＩＩＩ']
# ['心理学特殊講義XI']
# ['現代文芸論演習I']
# ['心理学演習I']
# ['近代文学特殊講義ＶＩＩ']
# ['近代文学特殊講義VIII']
# ['近代文学特殊講義Ｖ']
# ['心理学演習VII心理学実験演習IV']
# ['近代文学特殊講義ＩＩＩ']
# ['近代文学特殊講義ＩＶ']
# ['社会心理学概論I']
# ['社会学概論']
# ['社会心理学実習IV']
# ['特別演習（特別演習指導を含む）']
# ['社会調査']
# ['社会心理学実習II']
# ['社会心理学実習III']
# ['社会心理学実習I']
# ['現代文芸論演習ＩＩ']
# ['社会心理学演習V']
# ['社会学特殊講義V']
# ['社会学特殊講議III']
# ['社会学特殊講義VI']
# ['社会学特殊講義IV']
# ['社会心理学演習IV']
# ['社会心理学演習III']
# ['社会学特殊講義II']
# ['社会心理学演習I']
# ['社会学特殊講義I']
# ['社会心理学特殊講義V']
# ['近代文学特殊講義ＶＩ']
# ['社会心理学特殊講義III']
# ['社会心理学特殊講義II']
# ['社会心理学特殊講義VI']
# ['社会心理学特殊講義IV']
# ['社会学特殊講義VII']
# ['社会心理学特殊講義I']
# ['社会心理学演習II']
# ['社会心理学演習VI']
# ['ドイツ語学ドイツ文学演習I']
# ['フランス語学概論II']
# ['英語学英米文学特殊講義XIII']
# ['ドイツ語学ドイツ文学演習II']
# ['中国語学中国文学特殊講義XI']
# ['英語学英米文学演習IX']
# ['印度語学印度文学特殊講義III']
# ['中国語学中国文学特殊講義XIII']
# ['国語学演習IV']
# ['英語学概論I']
# ['中国語学中国文学特殊講義XII英語学英米文学特殊講義II']
# ['国文学特殊講義III']
# ['国文学演習IX']
# ['日本文学史']
# ['国文学概論']
# ['国文学特殊講義II']
# ['国文学特殊講義I']
# ['英語学英米文学特殊講義III']
# ['言語学演習VI']
# ['中国語学中国文学特殊講義X']
# ['国文学特殊講義XIII']
# ['日本書誌学概論']
# ['国語学特殊講義I']
# ['国語学特殊講義IV']
# ['国語学特殊講義III']
# ['国語学概論I']
# ['国文学特殊講義XI']
# ['国文学特殊講義X']
# ['国文学特殊講義IX']
# ['国語学概論II']
# ['国文学特殊講義VII']
# ['国語学特殊講義II']
# ['国文学特殊講義VIII']
# ['言語学演習VII']
# ['国文学特殊講義V']
# ['国文学特殊講義IV']
# ['国語学演習V']
# ['国文学特殊講義VI']
# ['英語圏言語文化特殊講義']
# ['印度語学印度文学特殊講義II']
# ['米文学史概説I']
# ['英文学史概説I']
# ['国文学特殊講義XII']
# ['英語学概論II']
# ['国語学演習II']
# ['国語学演習III']
# ['英語学英米文学特殊講義I']
# ['国語学特殊講義VIII']
# ['国語学特殊講義X']
# ['米文学史概説II']
# ['国語学特殊講義VII']
# ['印度語学印度文学特殊講義I']
# ['国語学特殊講義VI国語学演習VI']
# ['国語学演習I']
# ['国語学特殊講義V']
# ['英文学史概説II']
# ['印度語学概論I']
# ['印度文学史概説I']
# ['国文学演習VIII']
# ['印度語学概論II']
# ['特別演習(特別演習指導を含む)']
# ['国文学演習V']
# ['国文学演習IV']
# ['中国語学中国文学演習XI']
# ['国文学演習I']
# ['国文学演習II']
# ['国文学演習III']
# ['国文学特殊講義XV']
# ['国文学演習VI']
# ['国文学特殊講義XIV']
# ['中国語学中国文学特殊講義III']
# ['中国語学中国文学特殊講義I']
# ['国文学演習VII']
# ['中国言語文化論']
# ['中国語学中国文学演習X']
# ['中国語学中国文学特殊講義II']
# ['国文学演習XII']
# ['国文学演習XI']
# ['印度語学印度文学演習V']
# ['国語学特殊講義IX']
# ['印度語学印度文学演習II']
# ['印度語学印度文学演習I']
# ['印度語学印度文学演習III']
# ['印度語学印度文学演習IV']
# ['中国語学中国文学特殊講義VIII']
# ['中国語学中国文学特殊講義VII']
# ['印度語学印度文学演習VI']
# ['中国語学中国文学特殊講義VI']
# ['中国語学中国文学特殊講義V']
# ['中国語学中国文学特殊講義IV']
# ['国文学演習X']
# ['印度語学印度文学特殊講義IV']
# ['中国語学概論']
# ['英語学英米文学特殊講義IX']
# ['英語学英米文学特殊講義VII英語学英米文学特殊講義XII']
# ['英語学英米文学特殊講義X']
# ['英語学英米文学特殊講義V']
# ['英語学英米文学特殊講義IV']
# ['英語学英米文学特殊講義VIII']
# ['英語学英米文学特殊講義VI']
# ['英語学英米文学演習V']
# ['英語学英米文学演習IV']
# ['英語学英米文学演習III']
# ['英語学英米文学演習VII']
# ['英語学英米文学演習I']
# ['英語学英米文学演習VI']
# ['英語学英米文学特殊講義XIV']
# ['英語学英米文学演習II']
# ['英語圏言語文化演習']
# ['印度文学史概説II']
# ['英語学英米文学演習XV']
# ['英語学英米文学演習XIV']
# ['ドイツ語学概論I']
# ['英語学英米文学特殊講義XI']
# ['英語学英米文学演習XII']
# ['英語学英米文学演習XIII']
# ['フランス語学概論I']
# ['英語学英米文学演習XI']
# ['ドイツ語学ドイツ文学演習VII']
# ['英語学英米文学演習VIII']
# ['英語学英米文学演習XVI']
# ['ドイツ語学ドイツ文学演習VI']
# ['英語学英米文学演習X']
# ['ドイツ語学ドイツ文学演習III']
# ['ドイツ語学ドイツ文学特殊講義V']
# ['中国語学中国文学特殊講義IX']
# ['ドイツ語学ドイツ文学演習V']
# ['ドイツ語学ドイツ文学特殊講義II']
# ['ドイツ文学史概説II']
# ['ドイツ語学ドイツ文学演習IV']
# ['ドイツ語学ドイツ文学特殊講義IV']
# ['ドイツ語学ドイツ文学特殊講義I']
# ['ドイツ語学概論II']
# ['ドイツ語学ドイツ文学演習VIII']
# ['ドイツ文学史概説I']
# ['ドイツ語圏言語文化']
# ['ドイツ語学ドイツ文学特殊講義III言語学演習V']
# ['言語学演習IV']
# ['言語学演習III']
# ['考古学特殊講義XI']
# ['考古学特殊講義XII']
# ['言語学特殊講義VI']
# ['考古学演習V']
# ['美術史学特殊講義VI']
# ['西洋史学研究入門']
# ['西洋史学特殊講義X']
# ['西洋史学演習VII']
# ['西洋史学特殊講義I']
# ['美術史学特殊講義XV']
# ['西洋史学演習V']
# ['美術史学特殊講義XVI']
# ['西洋史学演習IV']
# ['日本史学演習XIII']
# ['日本史学演習XI']
# ['東洋史学特殊講義IX']
# ['東洋史学演習I']
# ['日本史学演習X']
# ['西洋史学特殊講義XI']
# ['博物館学実習B']
# ['東洋史学特殊講義VIII']
# ['言語学概論I']
# ['西洋史学演習VI']
# ['言語学概論II']
# ['野外考古学II']
# ['考古学特殊講義I']
# ['日本史学演習XII']
# ['美術史学演習VII']
# ['美術史学演習III']
# ['考古学概論II']
# ['考古学概論I']
# ['美術史学演習VI']
# ['西洋史学演習X']
# ['美術史学演習IV']
# ['美術史学演習V']
# ['野外考古学I']
# ['東洋史学特殊講義V']
# ['西洋史学演習VIII']
# ['東洋史学特殊講義IV']
# ['美術史学演習I東洋史学特殊講義III']
# ['東洋史学研究入門']
# ['東洋史学特殊講義I']
# ['美術史学演習II']
# ['東洋史学特殊講義II']
# ['日本史学演習VI']
# ['日本史学演習IX']
# ['東洋史学特殊講義VI']
# ['日本史学演習VII']
# ['西洋史学演習IX']
# ['西洋史学演習I']
# ['日本史学演習V']
# ['西洋史学演習II']
# ['日本史学演習VIII']
# ['美術史学特殊講義XIV']
# ['西洋史学特殊講義XII']
# ['西洋史学演習III']
# ['美術史学特殊講義XIII']
# ['美術史学特殊講義XII']
# ['美術史学特殊講義XI']
# ['美術史学特殊講義X']
# ['美術史学特殊講義VIII']
# ['東洋史学演習VII']
# ['東洋史学演習VIII']
# ['東洋史学演習VI']
# ['西洋史学特殊講義XIII']
# ['東洋史学演習V']
# ['美術史学特殊講義IX']
# ['東洋史学演習IV']
# ['西洋史学特殊講義IX']
# ['美術史学特殊講義VII']
# ['東洋史学演習III']
# ['西洋史学特殊講義VIII']
# ['東洋史学演習II']
# ['西洋史学特殊講義IV']
# ['西洋史学特殊講義VII']
# ['西洋史学特殊講義XIV']
# ['考古学演習III']
# ['西洋史学特殊講義II']
# ['西洋史学特殊講義III']
# ['考古学演習I']
# ['考古学演習IV']
# ['考古学特殊講義XVI西洋史学特殊講義V']
# ['考古学特殊講義IX']
# ['考古学特殊講義X']
# ['考古学特殊講義VII']
# ['考古学特殊講義VIII']
# ['考古学特殊講義VI']
# ['考古学特殊講義V']
# ['考古学特殊講義XV']
# ['考古学特殊講義IV']
# ['美術史学特殊講義V']
# ['考古学特殊講義II']
# ['考古学特殊講義XIV']
# ['考古学特殊講義III']
# ['美術史学特殊講義II']
# ['美術史学特殊講義I']
# ['美術史調査方法論I']
# ['考古学演習VI']
# ['西洋史学特殊講義VI']
# ['美術史調査方法論II']
# ['考古学演習II']
# ['美術史学特殊講義III']
# ['考古学特殊講義XIII']
# ['比較言語学II']
# ['言語学特殊講義V']
# ['比較言語学I']
# ['言語学特殊講義IV']
# ['音声学I']
# ['音声学II']
# ['言語学演習I']
# ['言語学特殊講義XI']
# ['美術史学特殊講義IV']
# ['言語学演習II']
# ['言語学特殊講義VIII']
# ['言語学特殊講義VII']
# ['言語学特殊講義III']
# ['言語学特殊講義X']
# ['言語学特殊講義II']
# ['言語学特殊講義I']
# ['日本史学特殊講義VII']
# ['日本史学特殊講義VIII']
# ['日本史学特殊講義IX']
# ['史学概論']
# ['言語学特殊講義IX原典講読III']
# ['日本史学演習IV']
# ['美学芸術学特殊講義V']
# ['古文書学特殊講義I']
# ['東洋倫理思想史概説I']
# ['美学史講義']
# ['インド哲学仏教学演習III']
# ['イスラム学特殊講義I']
# ['インド哲学仏教学特殊講義I']
# ['比較仏教論']
# ['仏教概論I']
# ['インド哲学史概説II']
# ['インド哲学史概説I']
# ['宗教学宗教史学特殊講義III']
# ['美学芸術学特殊講義III']
# ['中国思想文化学演習III']
# ['イスラム史概説']
# ['中国思想文化学演習IV']
# ['イスラム学概論I']
# ['仏教概論II']
# ['美学芸術学演習IV']
# ['美学芸術学特殊講義IV']
# ['インド哲学概論']
# ['美学芸術学演習III']
# ['美学芸術学演習I']
# ['美学芸術学演習II']
# ['インド哲学仏教学演習VI']
# ['インド哲学仏教学演習II']
# ['インド哲学仏教学演習V']
# ['インド哲学仏教学特殊講義VI']
# ['インド哲学仏教学演習I']
# ['インド哲学仏教学特殊講義IV']
# ['インド哲学仏教学特殊講義VII']
# ['イスラム学概論II']
# ['インド哲学仏教学特殊講義III']
# ['原典講読II']
# ['インド哲学仏教学特殊講義V']
# ['倫理学概論I']
# ['西洋倫理思想史概説I']
# ['西洋倫理思想史概説II']
# ['倫理学概論II']
# ['倫理学演習IV']
# ['インド哲学仏教学演習IV倫理学演習I']
# ['倫理学演習II']
# ['倫理学特殊講義IV']
# ['インド哲学仏教学特殊講義II']
# ['倫理学特殊講義I']
# ['インド哲学仏教学演習VIII']
# ['卒業論文(卒業論文指導を含む)']
# ['倫理学演習III']
# ['インド哲学仏教学演習VII']
# ['倫理学特殊講義II']
# ['原典講読VII']
# ['美学芸術学特殊講義II']
# ['原典講読IV']
# ['美学芸術学特殊講義I']
# ['宗教学演習VI']
# ['原典講読VI']
# ['宗教学演習VII']
# ['原典講読V']
# ['宗教学演習II']
# ['東洋倫理思想史概説II']
# ['宗教学演習V']
# ['宗教学宗教史学特殊講義V']
# ['倫理学特殊講義III']
# ['宗教学演習III']
# ['宗教学演習I']
# ['宗教学宗教史学特殊講義VI']
# ['原典講読VIII']
# ['日本史学演習I']
# ['日本史学演習III']
# ['宗教学宗教史学特殊講義IV']
# ['日本史学特殊講義XIV']
# ['日本史学特殊講義X']
# ['日本史学特殊講義XV']
# ['日本史学特殊講義XII']
# ['宗教学演習IV']
# ['宗教学宗教史学特殊講義I']
# ['日本史学演習II']
# ['宗教史概説III']
# ['日本史学特殊講義XIII']
# ['日本史学特殊講義XI']
# ['宗教学概論II']
# ['宗教史概説IV']
# ['宗教学概論I原典講読I']
# ['宗教史概説II']
# ['宗教史学演習III']
# ['宗教学宗教史学特殊講義II']
# ['宗教史概説I']
# ['宗教学演習VIII']
# ['宗教史学演習II']
# ['芸術学概論']
# ['イスラム学演習II']
# ['イスラム学演習III']
# ['イスラム学演習IV']
# ['イスラム学演習I']
# ['日本史学特殊講義VI']
# ['宗教史学演習I']
# ['美学概論']
# ['日本史学特殊講義V']
# ['日本史学特殊講義II']
# ['古文書学特殊講義II']
# ['日本史学特殊講義III']
# ['日本史学特殊講義IV']
# ['日本史学特殊講義I']
# ['イスラム学特殊講義II']
# ['哲学特殊講義III']
# ['イスラム学特殊講義IV']
# ['中国思想文化学演習II']
# ['応用倫理演習IV']
# ['哲学特殊講義IV']
# ['生物情報科学特別講義Ⅰ']
# ['中国思想文化学演習I']
# ['多分野講義V']
# ['人類学演習II']
# ['バイオメトリックス']
# ['植物発生学I']
# ['動物生理化学']
# ['動物発生学II']
# ['イスラム学特殊講義III']
# ['植物科学野外実習II']
# ['理学クラスター講義III']
# ['古人類学I']
# ['科学英語']
# ['研究倫理']
# ['生物科学セミナーIII']
# ['生物科学特論IV生物科学特論II']
# ['海洋生物学']
# ['遺伝子機能学']
# ['生態系機構論']
# ['生態発生学']
# ['生物科学特論III']
# ['生物科学セミナーIV']
# ['進化発生生物学']
# ['植物発生学II']
# ['生物科学特別講義II']
# ['生物科学特論I']
# ['集団生物学I']
# ['植物系統分類学']
# ['動物生理学II']
# ['動物生理学I']
# ['植物科学野外実習III']
# ['植物生理学II']
# ['人類学演習I']
# ['動物発生学I']
# ['生体人類学']
# ['人類遺伝学実習']
# ['人体生化学実習']
# ['植物生理学I']
# ['人類学野外実習']
# ['人体解剖学実習']
# ['生体調節機構学']
# ['情報科学実験']
# ['生物情報科学特別演習・実験II']
# ['生物情報科学特別演習・実験I']
# ['特別臨海実習']
# ['人類学特別講義III']
# ['生理人類学']
# ['進化生態学']
# ['系統進化学']
# ['人類遺伝学']
# ['多分野講義II']
# ['多分野講義I']
# ['先史学実習']
# ['多分野講義IV']
# ['人類生体機構学']
# ['研究倫理入門']
# ['ゲノム配列解析論I']
# ['生命情報科学Iシステム生物学']
# ['生物情報ソフトウェア論I']
# ['ゲノム生物学']
# ['情報基礎実験']
# ['生物情報実験法']
# ['生命科学基礎実験']
# ['生物データマイニング論']
# ['生物化学実験']
# ['生物統計論']
# ['生物情報科学演習II']
# ['生物情報科学演習I']
# ['応用倫理演習III']
# ['生命情報表現論']
# ['応用倫理演習I']
# ['ゲノム配列解析論II']
# ['応用倫理特殊講義IV']
# ['応用倫理演習II']
# ['応用倫理特殊講義I']
# ['理論生物学']
# ['応用倫理特殊講義II']
# ['死生学演習III']
# ['生物情報科学II']
# ['博物館科学表現実習']
# ['生物情報科学I']
# ['多分野講義III']
# ['生物情報科学特別講義III']
# ['人体組織学実習']
# ['応用倫理特殊講義III']
# ['西洋哲学史概説第2部I']
# ['哲学特殊講義II']
# ['哲学特殊講義I']
# ['西洋哲学史概説第1部I']
# ['哲学概論II']
# ['哲学概論I']
# ['中国思想文化学特殊講義IV']
# ['西洋哲学史概説第1部II']
# ['中国思想文化学特殊講義V']
# ['中国思想文化学特殊講義III']
# ['中国思想文化学特殊講義I']
# ['生物情報科学特別講義IV']
# ['中国思想文化史概説I']
# ['中国思想文化史概説II']
# ['哲学演習VIII生物情報ソフトウェア論II']
# ['哲学演習VI']
# ['中国思想文化学概論II']
# ['哲学演習IV']
# ['中国思想文化学特殊講義II']
# ['哲学演習III']
# ['哲学演習V']
# ['哲学演習VII']
# ['応用倫理概論']
# ['哲学演習I']
# ['中国思想文化学概論I']
# ['哲学演習II']
# ['西洋哲学史概説第2部II']
# ['有機化学演習']
# ['有機化学特論II']
# ['地球生命科学']
# ['化学特別講義Ⅴ']
# ['化学特別講義Ⅵ']
# ['有機化学特論I']
# ['物理化学特論II']
# ['化学特別実験']
# ['天体輻射論I']
# ['資源地質学']
# ['植物科学野外実習I']
# ['地球力学']
# ['天体物理学演習II']
# ['弾性波動論']
# ['地球電磁気学']
# ['大気海洋循環学']
# ['気象学']
# ['宇宙空間物理学I']
# ['大気海洋物質科学']
# ['計算天文学I']
# ['地球流体力学II']
# ['弾性体力学']
# ['地震物理学']
# ['地球流体力学I']
# ['天体輻射論II']
# ['地球惑星物理学特別研究']
# ['植物科学臨海実習']
# ['地球惑星内部物質科学']
# ['地球惑星物理学実験']
# ['大気海洋系物理学地球内部ダイナミクス']
# ['宇宙空間物理学II']
# ['地球惑星物理学基礎演習Ⅳ']
# ['海洋物理学']
# ['惑星大気学']
# ['地球惑星化学実験']
# ['地球惑星物理学特別演習']
# ['地球物理データ解析']
# ['地球惑星システム学基礎論']
# ['地球惑星物理学観測実習']
# ['系外惑星']
# ['太陽恒星物理学']
# ['地球惑星物理学演習']
# ['地球物理数値解析']
# ['地球惑星物理学基礎演習Ⅲ']
# ['星間物理学II']
# ['天文学ゼミナール']
# ['基礎天文学実験']
# ['博物館資料保存論']
# ['リモートセンシング・GISおよび実習']
# ['水圏環境学']
# ['比較惑星学基礎論']
# ['基礎天文学観測']
# ['星間物理学I']
# ['地球史学']
# ['天文学課題研究I']
# ['宇宙惑星物質進化学']
# ['古生物学']
# ['宇宙論']
# ['恒星進化論']
# ['天文学課題研究II']
# ['天体観測学']
# ['位置天文学・天体力学']
# ['銀河天文学']
# ['地球惑星環境学演習']
# ['地球惑星環境学実習']
# ['地球惑星環境学野外調査I']
# ['地球惑星環境学特別研究']
# ['地球惑星環境学野外調査III']
# ['地球環境化学実習']
# ['地球惑星環境学野外調査II']
# ['結晶学']
# ['惑星地質学地球惑星環境学野外巡検III']
# ['物理化学演習']
# ['無機分析化学演習']
# ['結晶学実習']
# ['分析化学II（各論）']
# ['無機分析化学特論']
# ['有機化学III（反応論）']
# ['地球物質循環学']
# ['天然物有機化学']
# ['固体化学']
# ['生体物質化学II']
# ['細胞分子生物学I']
# ['有機化学IV（合成）']
# ['分子遺伝学']
# ['生物物理化学I']
# ['生物化学演習I']
# ['生物物理化学II']
# ['細胞生理化学']
# ['細胞分子生物学II']
# ['地球惑星環境学基礎演習II']
# ['地球惑星環境学野外巡検I']
# ['造岩鉱物光学実習']
# ['生物化学演習II']
# ['固体地球科学']
# ['生体物質化学I']
# ['地球生命進化学実習']
# ['地球惑星物理化学']
# ['構造地質学']
# ['地形・地質調査法および実習']
# ['古気候・古海洋学']
# ['岩石組織学実習I']
# ['人間-環境システム学']
# ['地球生態学および実習']
# ['生物多様性科学および実習']
# ['地球惑星物理化学演習']
# ['地形学']
# ['地球生命進化学']
# ['化学特別講義Ⅳ']
# ['岩石組織学実習II']
# ['基礎化学英語演習Ⅰ']
# ['無機化学II（無機化合物論）']
# ['物理化学実験']
# ['量子化学Ⅲ地球惑星環境学国際研修II']
# ['地球環境化学']
# ['生命分子化学']
# ['地球惑星環境学国際研修I']
# ['有機化学実験']
# ['宇宙地球化学']
# ['固体機器分析学']
# ['生物化学特別実験I']
# ['生物化学特別実験II']
# ['生物化学実験法']
# ['分子生命科学I']
# ['先端鉱物学']
# ['気候システム学']
# ['分子生命科学II']
# ['分子生命科学III']
# ['細胞情報学']
# ['物理化学特論I']
# ['酵素学']
# ['分析化学無機化学実験']
# ['有機化学II（構造論）']
# ['無機化学III（錯体化学）']
# ['生物化学実験I']
# ['生物化学実験II']
# ['地球化学']
# ['化学反応学']
# ['化学熱力学II']
# ['構造化学']
# ['動物学臨海実習']
# ['生物科学専門実習III']
# ['科学英語演習']
# ['生物科学専門実習II']
# ['生物科学特別実習I']
# ['生物科学特別実習II']
# ['生物科学共通実習']
# ['人体解剖学']
# ['人体生化学']
# ['生物統計学演習']
# ['生物科学専門実習I']
# ['生物科学特別実習III']
# ['生物科学専門実習IV']
# ['形態人類学実習']
# ['分子進化学']
# ['人類生物学実習物理学ゼミナール']
# ['化学物理学']
# ['一般相対論']
# ['離散数学']
# ['プロセッサ・コンパイラ実験']
# ['量子計算科学']
# ['現代実験物理学II']
# ['解析学XE']
# ['代数学特別演習II']
# ['確率統計学III']
# ['代数学XH']
# ['幾何学XA']
# ['幾何学Ⅱb']
# ['情報科学特別講義IV']
# ['応用数学XG']
# ['応用数学XF']
# ['数学続論XB']
# ['幾何学特別演習Ib']
# ['解析学特別演習Ib']
# ['数学続論XA']
# ['代数学特別演習Ib']
# ['代数学特別演習Ia']
# ['解析学Vb']
# ['応用数学XE']
# ['解析学Va']
# ['応用数学XB']
# ['解析学Ⅵa']
# ['代数学XG']
# ['解析学XH']
# ['幾何学特別演習Ia']
# ['解析学XG']
# ['応用数学XC（本郷）']
# ['保険理論']
# ['応用数学XD']
# ['代数学Ib']
# ['確率統計学XF']
# ['確率統計学XD']
# ['代数学Ia']
# ['解析学Ⅵb']
# ['確率統計学XC']
# ['応用数学XA']
# ['解析学特別演習Ia']
# ['代数学XE確率統計学基礎']
# ['解析学XC（本郷）']
# ['解析学XF']
# ['数学史']
# ['幾何学Ⅱa']
# ['確率統計学XB']
# ['代数学XF']
# ['代数学Ⅱb']
# ['代数学XB']
# ['代数学XA']
# ['確率統計学XA']
# ['代数学Ⅱa']
# ['複素解析学Ⅱb']
# ['解析学Ⅳa']
# ['解析学XD']
# ['解析学XA']
# ['解析学VIII']
# ['解析学XB']
# ['幾何学XF']
# ['幾何学XE']
# ['幾何学Ia']
# ['幾何学XB']
# ['幾何学Ib']
# ['解析学Ⅳb']
# ['確率統計学XE']
# ['複素解析学特別演習']
# ['代数学特別演習I']
# ['解析学IV']
# ['幾何学特別演習I']
# ['解析学特別演習I']
# ['幾何学I']
# ['代数学XC（本郷）']
# ['複素解析学II']
# ['数理科学続論D']
# ['数理科学続論C']
# ['幾何学XG']
# ['幾何学特別演習II']
# ['数学続論XE']
# ['解析学特別演習Ⅲ']
# ['数理科学続論A']
# ['数学続論XD']
# ['計算数理演習b']
# ['幾何学特別演習Ⅱb数学続論XC']
# ['解析学特別演習Ⅱ']
# ['計算数理演習a']
# ['代数学特別演習Ⅱb']
# ['複素解析学Ⅱa']
# ['代数学特別演習Ⅱa']
# ['複素解析学特別演習b']
# ['数理科学続論J']
# ['数理科学続論I']
# ['数学特別講義IV']
# ['数学特別講義III']
# ['幾何学特別演習Ⅱa']
# ['複素解析学特別演習a']
# ['解析学特別演習Ⅱa']
# ['数理科学続論B']
# ['解析学特別演習Ⅱb']
# ['量子力学II']
# ['統計力学II']
# ['解析学特別演習Ⅲa']
# ['統計力学I']
# ['知識処理論']
# ['解析学特別演習Ⅲb']
# ['ハードウエア実験']
# ['関数・論理型プログラミング実験']
# ['コンピュータネットワーク']
# ['代数学I']
# ['論文構成法']
# ['情報科学演習III']
# ['コンピュータグラフィクス論']
# ['情報科学演習II']
# ['情報科学特別演習']
# ['リアルタイムシステム']
# ['連続系アルゴリズム']
# ['システムプログラミング実験']
# ['知能システム論']
# ['情報論理']
# ['言語モデル論']
# ['離散アルゴリズム論']
# ['言語処理系論']
# ['計算アルゴリズム論']
# ['計算機言語論']
# ['情報と職業']
# ['自然計算情報科学とバイオインフォマティクス']
# ['計算機構成論']
# ['計算科学シミュレーション']
# ['情報科学演習I']
# ['情報社会及び情報倫理']
# ['情報科学特別講義V']
# ['固体物理学I']
# ['流体力学']
# ['物理学演習IV']
# ['物理学演習III']
# ['固体物理学II']
# ['物理学演習V']
# ['電子回路論']
# ['場の量子論I']
# ['現代物理学入門']
# ['場の量子論II']
# ['電磁気学III']
# ['計算機実験II']
# ['量子光学']
# ['物理学のための科学英語特論']
# ['宇宙物理学']
# ['固体物理学III']
# ['生物物理学特論II']
# ['プラズマ物理学']
# ['統計力学特論']
# ['サブアトミック物理学']
# ['計算機実験I']
# ['原子核物理学']
# ['電磁気学II']
# ['現代実験物理学I']
# ['素粒子物理学']
# ['理論演習I']
# ['特別実験II']
# ['量子力学III']
# ['物理学実験I']
# ['物理数学III']
# ['物理学実験II']
# ['特別実験I']
# ['理論演習II']
# ['環境倫理']
# ['食品衛生学実習']
# ['生命倫理']
# ['木質構造科学演習普遍性生物学']
# ['測量・空間情報解析実習']
# ['緑地環境学研究演習']
# ['計算数理I']
# ['確率統計学II']
# ['計算数学I']
# ['計算数学II']
# ['卒業論文（緑地環境学専修）']
# ['卒業論文（木質構造科学専修）']
# ['水圏生物科学実験Ⅳ']
# ['水圏生物科学実験Ⅰ']
# ['数学講究XA']
# ['数学輪講']
# ['森林土壌学実験']
# ['水圏生物科学実験Ⅲ']
# ['確率統計学I']
# ['森林実習']
# ['水圏生物科学実験Ⅱ']
# ['卒業論文（森林生物科学専修）']
# ['フィールド科学演習']
# ['農場実習']
# ['沿岸生態学実習']
# ['森圏管理学実習']
# ['卒業論文（フィールド科学専修）']
# ['卒業論文（農業・資源経済学専修）']
# ['生物多様性科学実習']
# ['森林科学総合実習']
# ['農業・資源経済学研究演習']
# ['放射線生物学']
# ['森林利用学実習']
# ['臨床行動学']
# ['森林保全学実習']
# ['科学プレゼンテーション']
# ['野生動物医学']
# ['医療面接・コミュニケーション']
# ['産業動物臨床学Ⅱ']
# ['森林政策学演習']
# ['森林経理学実習']
# ['産業動物臨床学Ⅰ']
# ['森林風景計画実習']
# ['獣医倫理・動物福祉学']
# ['森林植物学実験']
# ['産業動物臨床学Ⅲ応用生物学研究演習']
# ['造林学実験']
# ['フィールド農学応用実習']
# ['計算数理II']
# ['応用生物学専門実験']
# ['卒業論文（応用生物学専修）']
# ['フィールド農学基礎実習']
# ['農家実習']
# ['森林動物学実験']
# ['応用生物学基礎実験Ⅰ']
# ['応用生物学基礎実験Ⅱ']
# ['現象数理II']
# ['生命化学・工学実習']
# ['応用生物化学実験']
# ['卒業論文（生命化学・工学専修）']
# ['応用微生物学実験']
# ['現象数理III']
# ['現象数理I']
# ['幾何学III']
# ['解析学VII']
# ['幾何学II']
# ['代数学II']
# ['解析学VI']
# ['数学講究XB']
# ['動物生命システム科学実習Ⅳ']
# ['代数学III']
# ['応用物理工学実験']
# ['動物生命システム科学実習Ⅱ']
# ['動物生命・形態学実習']
# ['応用環境科学実験']
# ['解析学V']
# ['動物生命・牧場実習']
# ['水産実習']
# ['保全生態学実習']
# ['漁業学実習']
# ['動物生命システム科学実習Ⅲ']
# ['数学特別講究']
# ['卒業論文（生物素材化学専修）']
# ['動物生命システム科学実習Ⅰ']
# ['緑地環境実地実習']
# ['生物素材化学演習']
# ['生物素材化学実験Ⅱ']
# ['緑地デザイン実習生物素材化学実習']
# ['ランドスケープエコロジー実習']
# ['卒業論文（水圏生物科学専修）']
# ['生物素材化学実験Ⅰ']
# ['生物材料化学実験']
# ['バイオマス科学実習']
# ['動物生命システム科学演習']
# ['動物生命システム科学実習Ⅴ']
# ['生物材料生物学実験']
# ['生物材料物理学実験']
# ['情報処理演習']
# ['動物生命システム科学実習Ⅵ']
# ['生物・環境工学実験Ⅲ']
# ['卒業論文（動物生命システム科学専修）']
# ['生物環境工学演習']
# ['生物・環境工学実験Ⅰ']
# ['応用解析および演習Ⅰ']
# ['建築設計製図演習Ⅱ']
# ['応用解析および演習Ⅱ']
# ['木質構造科学実習']
# ['建築設計製図演習Ⅰ']
# ['森林科学実習']
# ['卒業論文（森林環境資源科学専修）']
# ['環境設計演習']
# ['水理学演習']
# ['国際開発農学概論']
# ['英語表現法']
# ['国際農学情報処理演習']
# ['測量学実習']
# ['国際農学実験・実習Ⅱ']
# ['国際農学実験・実習Ⅰ']
# ['牧場実習']
# ['木質構造科学実験']
# ['臨海実習']
# ['水圏生物科学実習']
# ['組織学実習']
# ['建築設計製図Ⅲ']
# ['細菌学実習']
# ['基礎臨床学実習Ⅱ']
# ['卒業論文（国際開発農学専修）']
# ['動物衛生学実習']
# ['寄生虫学実習']
# ['基礎臨床学実習Ⅰ生物・環境工学実験Ⅱ']
# ['獣医公衆衛生学実習']
# ['獣医学基礎実習']
# ['生体機能学実習']
# ['卒業論文（獣医学専修）']
# ['ウイルス学・免疫学実習']
# ['実験動物学実習']
# ['小動物内科臨床実習']
# ['応用獣医学インターンシップ']
# ['大動物臨床・臨床繁殖実習']
# ['海外実習']
# ['総合臨床学インターンシップ']
# ['農学リテラシー']
# ['基礎臨床学実習Ⅲ']
# ['毒性学実習']
# ['病理学実習']
# ['外科呼吸器循環器病学']
# ['小動物外科臨床実習']
# ['外科泌尿生殖器病学']
# ['地域農業マネジメント']
# ['構造力学']
# ['環境生物化学']
# ['農業史']
# ['バイオマス生物工学']
# ['植物バイオマス化学Ⅰ']
# ['景観解析']
# ['馬臨床学']
# ['植物バイオマス化学Ⅱ']
# ['界面科学']
# ['海洋生態学']
# ['農村計画学']
# ['森林リモートセンシング']
# ['リモートセンシング情報解析学']
# ['材料力学']
# ['測量学']
# ['自然共生社会論']
# ['都市農村計画学']
# ['生態工学']
# ['環境地水学']
# ['水利環境工学']
# ['生物環境工学']
# ['緑地計画学']
# ['制御工学ランドスケープエコロジー']
# ['農地環境工学']
# ['建築生産施工']
# ['森圏管理学']
# ['土壌物理学']
# ['ポストハーベスト工学']
# ['土質力学']
# ['生物環境情報工学']
# ['生物機械工学']
# ['水工システム学']
# ['森林生物化学']
# ['放射線動物科学']
# ['動物生命科学基礎']
# ['生物素材化学概論']
# ['臨床栄養学各論']
# ['水処理工学']
# ['植物環境システム学']
# ['生物多様性科学']
# ['植物繊維科学']
# ['有機反応機構']
# ['生殖生物学']
# ['生物材料組織学']
# ['高分子材料学Ⅱ']
# ['バイオマスエネルギー工学']
# ['高分子材料学Ⅰ']
# ['水産増養殖学']
# ['生体高分子科学']
# ['生物海洋学']
# ['水産資源学']
# ['木材化学']
# ['森林評価学']
# ['セルロース科学']
# ['生体計測情報学']
# ['森林生産工学']
# ['森林環境経済学']
# ['森林資源経済学']
# ['砂防工学']
# ['農業基盤計画学']
# ['国際農業プロジェクト論']
# ['臨床栄養学総論']
# ['森林計測学']
# ['漁業学']
# ['国際農業工学国際水産開発学']
# ['レクリエーション計画論']
# ['国際森林学']
# ['国際植物利用学']
# ['森林生産基盤学']
# ['地域社会概論']
# ['沿岸環境動態論']
# ['国際森林環境学']
# ['森林社会学']
# ['建築設計製図Ⅱ']
# ['木質構造学']
# ['住宅計画論']
# ['建築住環境学']
# ['建築設計製図Ⅰ']
# ['木質材料学Ⅰ']
# ['比較農業法']
# ['国際農業経済論']
# ['フードシステム論']
# ['農村開発論']
# ['開発経済学']
# ['比較農業政策論']
# ['国際動物資源科学']
# ['農業経営学']
# ['農業経済学']
# ['ゲーム理論基礎']
# ['農業経営概論']
# ['木材物理学']
# ['国際農業生態学']
# ['生物プロセス工学']
# ['応用数量経済分析']
# ['数量経済分析']
# ['動物感染症学']
# ['農業IoT概論']
# ['病理学総論']
# ['ウイルス学']
# ['生物・環境熱力学']
# ['木質材料学Ⅱ']
# ['生物環境要素学']
# ['細胞情報薬理学']
# ['薬理学各論']
# ['泌尿器病学']
# ['国際地域農業開発と生産者組織']
# ['臨床病理学総論呼吸循環器病学']
# ['内科学総論']
# ['内分泌病学Ⅱ']
# ['細菌学']
# ['獣医衛生学']
# ['毒性学']
# ['運動器病学']
# ['感染症・エキゾチックアニマル病学']
# ['公衆衛生学総論']
# ['神経外科学']
# ['神経病学']
# ['外科軟部組織病学']
# ['消化器病学']
# ['人獣共通感染症学']
# ['寄生虫学']
# ['家禽疾病学']
# ['臨床繁殖学']
# ['外科消化器病学']
# ['獣医事法規']
# ['外科学・手術学総論']
# ['獣医疫学']
# ['薬理学総論']
# ['環境衛生学']
# ['病理学各論']
# ['動物行動学']
# ['動物生命システム科学Ⅰ']
# ['実験動物学']
# ['ストレス生物学']
# ['造林学']
# ['微生物生理学']
# ['植物分子遺伝学']
# ['眼科学']
# ['食品免疫・腸管機能学']
# ['食品衛生学']
# ['生物有機化学']
# ['食品生物構造学']
# ['食品微生物学']
# ['農芸化学概論']
# ['森林水文学']
# ['園芸学Ⅰ']
# ['森林経理学']
# ['森林風景計画学']
# ['生物環境物理学森林政策学']
# ['森林利用学']
# ['生物制御化学']
# ['アジア生物環境学']
# ['自然環境学汎論']
# ['昆虫遺伝学']
# ['耕地生態学']
# ['農業気象学']
# ['栽培植物学']
# ['植物病理学']
# ['森林生態圏管理学']
# ['発酵工学']
# ['植物機能制御学']
# ['食品・生物機能化学']
# ['食品化学']
# ['植物生態学']
# ['栄養化学']
# ['基礎高分子化学']
# ['基礎物理化学']
# ['動物分類学']
# ['森林環境科学汎論']
# ['昆虫学']
# ['食品生化学']
# ['遺伝学']
# ['環境科学']
# ['有機化学']
# ['植物育種学']
# ['自然保護論']
# ['土壌生態学']
# ['作物学Ⅰ']
# ['環境土壌学']
# ['植物栄養学']
# ['応用動物科学概論']
# ['動物生態学']
# ['情報工学']
# ['流れ学']
# ['農業史概論']
# ['応用物理学']
# ['木質構造科学概論']
# ['動物細胞生物学']
# ['タンパク質・酵素学Ⅱ']
# ['タンパク質・酵素学Ⅰ']
# ['動物生理学生物無機化学']
# ['生物情報科学Ⅱ']
# ['生物化学']
# ['微生物遺伝学']
# ['微生物生態学']
# ['生物情報科学Ⅰ']
# ['昆虫系統分類学']
# ['農業資源経済学汎論']
# ['環境微生物学']
# ['園芸学Ⅱ']
# ['細胞微生物学']
# ['野生動物管理論']
# ['昆虫生理学']
# ['持続的植物生産学']
# ['応用微生物学']
# ['樹木学']
# ['樹木医学']
# ['作物学Ⅱ']
# ['植物分子生理学']
# ['森林生態生理学']
# ['集団遺伝学']
# ['森林土壌学']
# ['森林植物学']
# ['昆虫生態学']
# ['植物ウイルス学']
# ['植物分子育種学']
# ['森林遺伝育種学']
# ['植物細菌学']
# ['昆虫病理学']
# ['動物細胞生化学Ⅱ']
# ['森林生態学']
# ['昆虫利用学']
# ['動物細胞制御学']
# ['保全生態学']
# ['森林動物学']
# ['動物細胞生化学Ⅰ']
# ['応用遺伝学']
# ['栽培学']
# ['水産食品科学']
# ['応用免疫学']
# ['水生動物栄養学']
# ['水圏生物工学']
# ['浮遊生物学水生動物生理学']
# ['水圏環境科学']
# ['水生無脊椎動物学']
# ['水生脊椎動物学']
# ['水生植物学']
# ['水生生物化学']
# ['獣医解剖学']
# ['魚類発生学']
# ['発生学']
# ['内分泌・代謝生理学']
# ['組織学']
# ['体液生理学']
# ['神経生理学']
# ['水圏天然物化学']
# ['動物生命システム科学Ⅱ']
# ['魚類遺伝育種学']
# ['バイオマス利用学概論']
# ['化合物の多様性と生理機能Ⅱ']
# ['ヨーロッパ政治史']
# ['民法演習（外国語科目）']
# ['日本近代法史演習']
# ['フランス法演習（外国語科目）']
# ['刑事訴訟法演習（外国語科目）']
# ['日本政治外交史']
# ['東洋法制史演習（外国語科目）']
# ['民事訴訟法第２部']
# ['政治学史演習（外国語科目）']
# ['行政学演習']
# ['国際法演習（外国語科目）']
# ['民法演習(外国語科目）']
# ['アジア政治外交史演習']
# ['刑事学演習（外国語科目）']
# ['民法基礎演習']
# ['金融法演習']
# ['民法演習']
# ['日本政治思想史演習']
# ['商法第１部']
# ['経済法演習（外国語科目）']
# ['民事訴訟法第１部']
# ['租税法演習（外国語科目）']
# ['国際私法演習（外国語科目）']
# ['刑事訴訟法演習']
# ['憲法演習法教育演習']
# ['刑法第１部']
# ['商法演習（外国語科目）']
# ['民事訴訟法演習（外国語科目）']
# ['刑法第２部']
# ['民事訴訟法演習']
# ['英米法演習（外国語科目）']
# ['比較法演習（外国語科目）']
# ['行政法演習（外国語科目）']
# ['ローマ法演習（外国語科目）']
# ['知的財産法']
# ['政治学演習（外国語科目）']
# ['国際私法']
# ['政治学演習']
# ['フランス法']
# ['英米法']
# ['現代政治理論']
# ['ドイツ法']
# ['刑法演習']
# ['日本法制史演習']
# ['イスラーム法演習（外国語科目）']
# ['ヨーロッパ政治史演習（外国語科目）']
# ['都市行政学演習']
# ['商法第３部']
# ['行政学']
# ['比較政治演習（外国語科目）']
# ['ロシア･旧ソ連史演習（外国語科目）']
# ['商法第２部']
# ['刑法演習（外国語科目）']
# ['財政学']
# ['民事訴訟法第３部']
# ['日本政治']
# ['中国法演習（外国語科目）']
# ['国際法第２部']
# ['行政法第２部']
# ['国際法第１部']
# ['刑事訴訟法']
# ['商法演習(外国語科目）']
# ['行政法第１部']
# ['植物生理学']
# ['基礎生物化学']
# ['基礎微生物学']
# ['刑法演習(外国語科目）基礎有機化学']
# ['食の安全科学']
# ['化合物の多様性と生理機能Ⅰ']
# ['基礎分析化学']
# ['植物分類・形態学']
# ['政治学史演習(外国語科目)']
# ['森林資源と木材利用']
# ['水の環境科学']
# ['放射線環境学']
# ['生物の多様性と進化']
# ['土壌圏の科学']
# ['環境と生物の情報科学']
# ['政治学']
# ['環境と景観の生物学']
# ['人口と食糧']
# ['生態系の中の人類']
# ['民法第２部']
# ['民法第４部']
# ['民法第１部']
# ['国際政治演習（外国語科目）']
# ['知的財産法演習']
# ['国際政治演習']
# ['比較政治演習']
# ['ヨーロッパ法演習（外国語科目）']
# ['労働法演習（外国語科目）']
# ['労働法演習']
# ['民法第３部']
# ['アメリカ政治外交史演習（外国語科目）']
# ['現代法過程論演習']
# [' ']
# [['演習'], ['特殊'], ['講義'], ['科学'], ['研究'], ['工学'], ['社会'], ['コース'], ['日本'], ['文化'], ['文学'], ['理学'], ['化学'], ['語学'], ['実習'], ['生物'], ['共通'], ['基礎'], ['情報'], ['特別'], ['英語'], ['環境'], ['シス'], ['システム'], ['国語'], ['国際'], ['専門'], ['数理'], ['経済'], ['概論'], ['実験'], ['言語'], ['力学'], ['教育'], ['日本語'], ['物理'], ['史学'], ['応用'], ['中国'], ['フランス'], ['現代'], ['心理'], ['生命数学'], ['開講'], ['分析'], ['心理学'], ['教養'], ['思想'], ['統計'], ['ドイツ'], ['政治'], ['論文'], ['中国語'], ['解析'], ['アメリカ'], ['哲学'], ['アジア'], ['建築'], ['物質'], ['イタリア'], ['第一'], ['科目'], ['技術'], ['倫理'], ['グローバル'], ['朝鮮'], ['設計'], ['韓国'], ['物理学'], ['地域'], ['国文学'], ['テクスト'], ['社会学'], ['地球'], ['生物学'], ['中級'], ['材料'], ['動物'], ['西洋'], ['外国語'], ['総合'], ['フランス語'], ['理論'], ['初級'], ['経済学分子'], ['自然'], ['ドイツ語'], ['国語学'], ['構造'], ['宇宙'], ['指導'], ['社会科'], ['人類'], ['都市'], ['ロシア'], ['解析学'], ['生命科学'], ['基礎科学'], ['社会科学'], ['比較'], ['卒業'], ['森林'], ['歴史'], ['経営'], ['プロジェクト'], ['航空'], ['情報学'], ['情報工学'], ['イタリア語'], ['資源'], ['量子'], ['ラテンアメリカ'], ['概説'], ['計画'], ['エネルギー'], ['人類学'], ['自然科学'], ['上級'], ['英語学'], ['環境学'], ['卒業論文'], ['植物'], ['生態'], ['地理'], ['統合'], ['芸術'], ['英米文学教育法'], ['高度'], ['宗教'], ['相関'], ['関係'], ['広域'], ['会話'], ['日本史'], ['惑星'], ['科学技術'], ['国際関係'], ['計算'], ['イギリス'], ['電気'], ['機械'], ['中国語学'], ['文明'], ['考古学'], ['中国文学'], ['認知'], ['数理科学'], ['進化'], ['情報科'], ['スペイン'], ['理工学'], ['航空宇宙'], ['美術史'], ['西洋史'], ['生体'], ['農業'], ['生理'], ['電子'], ['マテ'], ['統計学'], ['東西文明'], ['プログラミング'], ['政策'], ['調査'], ['情報科学'], ['有機'], ['代数'], ['看護'], ['空間地域文化'], ['理I'], ['量子力学'], ['代数学'], ['金融'], ['東洋'], ['近代'], ['バイオ'], ['言語学'], ['文化人類学'], ['健康'], ['地中海'], ['フランス文学'], ['スペイン語'], ['幾何'], ['後期'], ['製図'], ['臨床'], ['幾何学'], ['東欧'], ['制御'], ['精密'], ['社会心理学'], ['国際社会'], ['ヨーロッパ'], ['行動'], ['有機化学'], ['国際関係論'], ['日本文化'], ['ロシア語'], ['組織'], ['マテリアル'], ['スラヴ'], ['フランス語学'], ['体力'], ['学際'], ['生理学'], ['生態学'], ['講読'], ['看護学'], ['インド哲学'], ['仏教'], ['生産人間'], ['開発'], ['原典'], ['表象'], ['現代思想'], ['経済史'], ['輪講'], ['東洋史'], ['東アジア'], ['学習'], ['セミナー'], ['計測'], ['ドイツ文学'], ['古典'], ['精読'], ['システム工学'], ['流体'], ['管理'], ['宗教学'], ['倫理学'], ['身体'], ['スポーツ'], ['統計力学'], ['物理化学'], ['ラテン語'], ['環境工学'], ['少人数'], ['行政'], ['高分子'], ['イタリア文学'], ['細胞'], ['遺伝'], ['公共'], ['専修'], ['デザイン'], ['都市工学'], ['物性'], ['確率'], ['印度'], ['実践'], ['コミュニケーション'], ['機能'], ['基盤入門'], ['データ'], ['アジア地域'], ['ラテンアメリカ研究'], ['資料'], ['産業'], ['マネジメント'], ['博物館'], ['流体力学'], ['文学史'], ['宗教史'], ['処理'], ['物質科学'], ['日本経済'], ['発生'], ['確率統計'], ['数学I'], ['アラビア語'], ['作文'], ['遺伝学'], ['教育学'], ['野外'], ['固体'], ['神経'], ['集中'], ['機構'], ['方法'], ['エシックス'], ['反応'], ['多様性'], ['理II'], ['読解'], ['死生学'], ['電磁'], ['微生物'], ['回路'], ['水圏'], ['医学'], ['推進'], ['美学'], ['イスラム'], ['分析化学'], ['外交政治学'], ['民族'], ['メディア'], ['フィールド'], ['民法'], ['総論'], ['材料力学'], ['システム情報'], ['無機'], ['磁気'], ['航空機'], ['近代文学'], ['西洋古典学'], ['芸術学'], ['医療'], ['比較文化'], ['交流'], ['行動科学'], ['生化学'], ['現代社会'], ['法学'], ['政治経済'], ['ため'], ['比較文学'], ['疫学'], ['表現'], ['リング'], ['夏季'], ['海洋'], ['計数'], ['プロセス'], ['手法'], ['空気'], ['獣医'], ['食品'], ['国際政治'], ['計量'], ['電磁気学'], ['複素解析'], ['シミュレーション'], ['技法'], ['循環'], ['熱力学地域研究'], ['北アメリカ'], ['ギリシア語'], ['造形'], ['利用'], ['会計'], ['教育社会学'], ['制御工学'], ['応用数学'], ['ソフトウェア'], ['文章'], ['通論'], ['空気力学'], ['解剖'], ['天文学'], ['木質'], ['農学'], ['衛生学'], ['栄養'], ['文化科学'], ['脳科学'], ['批評'], ['表象文化論'], ['発達'], ['方法論'], ['神経科学'], ['栄養学'], ['解剖学'], ['生体高分子'], ['無機化学'], ['生物多様性'], ['薬学'], ['薬理学'], ['医薬'], ['アメリカ文学'], ['財務'], ['戦略'], ['マクロ'], ['ファイナンス'], ['バイオマス'], ['病理学'], ['微生物学'], ['安全知能'], ['インターンシップ'], ['精密工学'], ['振動'], ['固体物理'], ['発生学'], ['惑星物理学'], ['動物学'], ['外科'], ['昆虫'], ['商法'], ['思想史'], ['分野'], ['協力'], ['応用倫理学'], ['トレーニング'], ['細胞生物学'], ['数学II'], ['分子生物学'], ['科学哲学'], ['地球科学'], ['国際法'], ['英語圏'], ['情報処理'], ['ヒンディー語'], ['ポルトガル語'], ['公衆衛生'], ['法制史'], ['原論'], ['労働経済'], ['数量'], ['経営史'], ['現代日本'], ['学校'], ['人体'], ['緑地'], ['数理工学'], ['機械工学'], ['デバイス'], ['冬季'], ['実地'], ['電気工学'], ['コンピュータ物理数学'], ['自動'], ['人文'], ['前期'], ['文芸'], ['および'], ['連続'], ['現象'], ['素材'], ['土壌'], ['水生'], ['第２部'], ['第１部'], ['フィールドワーク'], ['ビジネス'], ['科学技術社会論'], ['文法'], ['認知科学'], ['技術経営'], ['国際協力'], ['卒業研究'], ['数値'], ['最適化'],  ...
# 161

# %%
import json
import csv
import numpy as np
import pandas as pd
def count_df(courses,vocab):
    df={}
    for word_id, word in enumerate(vocab):
        count=0
        for c in courses:
            if word in c:
                count+=1
        df[word_id]=count
    return df
courses = list(open("course_list.csv"))
vocab = list(open("keyword_list.csv"))
df=count_df(courses,vocab)
print(len(df))
# Out:
# 4523

# %%
import numpy as np
def lec_word_matrix(courses, vocab):
    lec_word=np.zeros((len(courses),len(vocab)),dtype=int)
    for i in range(len(courses)):
        for j in range(len(vocab)):
            if vocab[j] in courses:
                lec_word[i][j]=1
    print(lec_word)
courses = list(open("course_list.csv"))
vocab = list(open("keyword_list.csv"))
lec_word_matrix(courses, vocab)
print(1)
